# %%
import re
import os
import nest_asyncio
import pandas as pd
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeoutError

nest_asyncio.apply()

# =========================================================
# SETTINGS
# =========================================================
OUTPUT_FILE = "propertyguru_extracted_listings.csv"
CHECKPOINT_EVERY = 50   # fewer writes = slightly faster

# =========================================================
# COLLECT LISTING LINKS FROM SEARCH RESULT PAGES
# =========================================================
SEARCH_PAGE_START = 1
SEARCH_PAGE_END = 750
CHECKPOINT_LINKS_FILE = "propertyguru_all_listing_links.csv"

SEARCH_URL_TEMPLATE = (
    "https://www.propertyguru.com.sg/property-for-sale/{page}"
    "?__NA=true"
    "&hdbEstate=1&hdbEstate=10&hdbEstate=2&hdbEstate=20&hdbEstate=21&hdbEstate=22"
    "&hdbEstate=23&hdbEstate=24&hdbEstate=25&hdbEstate=26&hdbEstate=27&hdbEstate=28"
    "&hdbEstate=11&hdbEstate=3&hdbEstate=4&hdbEstate=5&hdbEstate=6&hdbEstate=7"
    "&hdbEstate=8&hdbEstate=9&hdbEstate=12&hdbEstate=13&hdbEstate=14&hdbEstate=15"
    "&hdbEstate=17&hdbEstate=18&hdbEstate=19"
    "&search=true&listingType=sale&isCommercial=false&locale=en"
)

async def collect_listing_links():
    all_links = set()

    # resume if checkpoint exists
    if os.path.exists(CHECKPOINT_LINKS_FILE):
        old_links_df = pd.read_csv(CHECKPOINT_LINKS_FILE).astype(object)
        if "listing_url" in old_links_df.columns:
            all_links = set(old_links_df["listing_url"].dropna().astype(str).tolist())
            print(f"Loaded existing link checkpoint with {len(all_links)} listing URLs.")

    async with async_playwright() as p:
        context = await p.chromium.launch_persistent_context(
            "pg_search_profile_fast",
            headless=False,
            viewport={"width": 1440, "height": 900},
            args=["--disable-blink-features=AutomationControlled"]
        )

        page = context.pages[0] if context.pages else await context.new_page()

        print("=" * 80)
        print("Browser opened for search pages.")
        print("If you see Cloudflare / cookie banner / 'Just a moment...', solve it manually.")
        print("Waiting 10 seconds before starting...")
        print("=" * 80)
        await page.wait_for_timeout(10000)

        for page_num in range(SEARCH_PAGE_START, SEARCH_PAGE_END + 1):
            search_url = SEARCH_URL_TEMPLATE.format(page=page_num)
            print(f"\n[Search page {page_num}/{SEARCH_PAGE_END}] Opening: {search_url}")

            try:
                await page.goto(search_url, wait_until="domcontentloaded", timeout=45000)

                title = await page.title()
                if "just a moment" in title.lower() or "attention required" in title.lower():
                    print("Cloudflare detected. Solve it manually in the browser.")
                    await page.wait_for_timeout(20000)

                await page.wait_for_timeout(2500)

                # grab all hrefs from the page
                hrefs = await page.eval_on_selector_all(
                    "a",
                    """elements => elements.map(el => el.href).filter(Boolean)"""
                )

                page_links = set()

                for href in hrefs:
                    href = href.strip()

                    # keep only actual listing detail pages
                    if re.match(r"^https://www\.propertyguru\.com\.sg/listing/[^/\s]+.*$", href):
                        page_links.add(href)

                # small interaction if nothing was found yet
                if not page_links:
                    await page.mouse.move(250, 350)
                    await page.mouse.wheel(0, 1200)
                    await page.wait_for_timeout(1500)

                    hrefs = await page.eval_on_selector_all(
                        "a",
                        """elements => elements.map(el => el.href).filter(Boolean)"""
                    )

                    for href in hrefs:
                        href = href.strip()
                        if re.match(r"^https://www\.propertyguru\.com\.sg/listing/[^/\s]+.*$", href):
                            page_links.add(href)

                before_count = len(all_links)
                all_links.update(page_links)
                added_count = len(all_links) - before_count

                print(f"Found {len(page_links)} listing links. Added {added_count} new ones.")

                if page_num % 25 == 0:
                    temp_links_df = pd.DataFrame({"listing_url": sorted(all_links)})
                    temp_links_df.to_csv(CHECKPOINT_LINKS_FILE, index=False)
                    print(f"Saved link checkpoint at page {page_num}. Total unique listing URLs: {len(temp_links_df)}")

            except Exception as e:
                print(f"Error on search page {page_num}: {e}")

        await context.close()

    final_links_df = pd.DataFrame({"listing_url": sorted(all_links)})
    final_links_df.to_csv(CHECKPOINT_LINKS_FILE, index=False)

    print("\nFinished collecting listing links.")
    print("Total unique listing URLs collected:", len(final_links_df))

    return final_links_df



# =========================================================
# HELPER FUNCTIONS
# =========================================================
def normalize_text(text):
    if not text:
        return None
    text = text.replace("\xa0", " ")
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n+", "\n", text)
    return text.strip()

def extract_price(text):
    if not text:
        return None
    patterns = [
        r"(S\$\s?[\d,]+(?:\.\d+)?)",
        r"(S\$\s?[\d,.]+\s*(?:mil|million))"
    ]
    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return m.group(1).strip()
    return None

def extract_bedrooms(text):
    if not text:
        return None
    patterns = [
        r"(\d+)\s+bedrooms?",
        r"(\d+)\s+beds?",
        r"(\d+)\s+bed\b"
    ]
    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return m.group(1)
    return None

def extract_bathrooms(text):
    if not text:
        return None
    patterns = [
        r"(\d+)\s+bathrooms?",
        r"(\d+)\s+baths?",
        r"(\d+)\s+bath\b"
    ]
    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return m.group(1)
    return None

def extract_area(text):
    if not text:
        return None
    patterns = [
        r"(\d[\d,]*)\s*(sqft|sq ft|sq\.ft|sqm|m²)"
    ]
    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return f"{m.group(1)} {m.group(2)}"
    return None

def extract_floor(text):
    if not text:
        return None
    patterns = [
        r"floor level[:\s]+([A-Za-z0-9 \-]+)",
        r"located on[:\s]+([A-Za-z0-9 \-]+)",
        r"(\d{1,2}(?:st|nd|rd|th)\s+floor)",
        r"(high floor|mid floor|low floor)"
    ]
    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return m.group(1).strip()
    return None

def extract_tenure(text):
    if not text:
        return None
    patterns = [
        r"(99-Year Leasehold)",
        r"(999-Year Leasehold)",
        r"(\d{2,3}-Year Leasehold)",
        r"(Freehold)"
    ]
    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return m.group(1).strip()
    return None

def extract_property_type(text):
    if not text:
        return None
    candidates = [
        "HDB",
        "Condo",
        "Condominium",
        "Apartment",
        "Executive Condominium",
        "Landed House",
        "Terraced House",
        "Semi-Detached House",
        "Detached House",
        "Bungalow",
        "Walk-up Apartment",
        "Cluster House"
    ]
    for c in candidates:
        if re.search(rf"\b{re.escape(c)}\b", text, re.I):
            return c
    return None

def extract_listing_id(text):
    if not text:
        return None
    patterns = [
        r"listing id[:\s]+(\d+)",
        r"property id[:\s]+(\d+)"
    ]
    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return m.group(1)
    return None

def extract_title_from_text(text):
    if not text:
        return None
    lines = [x.strip() for x in text.split("\n") if x.strip()]
    for line in lines[:12]:
        if (
            len(line) > 5
            and "S$" not in line
            and "Property for Sale" not in line
            and "Buy" not in line
            and "Contact" not in line
        ):
            return line
    return lines[0] if lines else None

def extract_town(text):
    if not text:
        return None

    towns = [
        "Ang Mo Kio","Bedok","Bishan","Bukit Batok","Bukit Merah","Bukit Panjang",
        "Bukit Timah","Central Area","Choa Chu Kang","Clementi","Geylang","Hougang",
        "Jurong East","Jurong West","Kallang","Marine Parade","Pasir Ris","Punggol",
        "Queenstown","Sembawang","Sengkang","Serangoon","Tampines","Toa Payoh",
        "Woodlands","Yishun"
    ]

    for town in towns:
        if re.search(rf"\b{re.escape(town)}\b", text, re.I):
            return town
    return None

def extract_postal_code(text):
    if not text:
        return None

    patterns = [
        r"Singapore\s*\(?(\d{6})\)?",
        r"\b(\d{6})\b"
    ]

    for p in patterns:
        m = re.search(p, text, re.I)
        if m:
            return m.group(1).strip()
    return None

# =========================================================
# MAIN ENRICHMENT FUNCTION
# =========================================================
async def enrich_all_links(links_df):
    results = []

    done_urls = set()
    if os.path.exists(OUTPUT_FILE):
        old = pd.read_csv(OUTPUT_FILE).astype(object)
        if "listing_url" in old.columns:
            done_urls = set(old["listing_url"].dropna().astype(str).tolist())
            results = old.to_dict("records")
            print(f"Loaded existing checkpoint with {len(done_urls)} completed listings.")

    async with async_playwright() as p:
        context = await p.chromium.launch_persistent_context(
            "pg_detail_profile_fast",
            headless=False,
            viewport={"width": 1440, "height": 900},
            args=["--disable-blink-features=AutomationControlled"]
        )

        page = context.pages[0] if context.pages else await context.new_page()

        print("=" * 80)
        print("Browser opened.")
        print("If you see Cloudflare / cookie banner / 'Just a moment...', solve it manually.")
        print("Waiting 10 seconds before starting...")
        print("=" * 80)
        await page.wait_for_timeout(10000)

        total = len(links_df)

        for i, row in links_df.iterrows():
            url = str(row["listing_url"]).strip()

            if not url or url in done_urls:
                continue

            print(f"\n[{i+1}/{total}] Opening: {url}")

            try:
                # faster navigation
                await page.goto(url, wait_until="domcontentloaded", timeout=45000)

                # quick Cloudflare/title check
                title = await page.title()
                if "just a moment" in title.lower() or "attention required" in title.lower():
                    print("Cloudflare detected. Solve it manually in the browser.")
                    await page.wait_for_timeout(20000)
                    title = await page.title()

                # wait for real content instead of sleeping 10 seconds
                main_heading = None
                heading_selectors = ["h1", "[data-testid='listing-title']", "[class*='title']"]

                for selector in heading_selectors:
                    try:
                        await page.locator(selector).first.wait_for(timeout=4000)
                        texts = await page.locator(selector).all_inner_texts()
                        texts = [t.strip() for t in texts if t and t.strip()]
                        for h in texts:
                            if len(h) > 5 and "S$" not in h and "PropertyGuru" not in h:
                                main_heading = h
                                break
                        if main_heading:
                            break
                    except PlaywrightTimeoutError:
                        pass
                    except Exception:
                        pass

                # only do small interaction if heading wasn't found
                if not main_heading:
                    await page.mouse.move(250, 350)
                    await page.mouse.wheel(0, 900)
                    await page.wait_for_timeout(1500)

                    for selector in heading_selectors:
                        try:
                            texts = await page.locator(selector).all_inner_texts()
                            texts = [t.strip() for t in texts if t and t.strip()]
                            for h in texts:
                                if len(h) > 5 and "S$" not in h and "PropertyGuru" not in h:
                                    main_heading = h
                                    break
                            if main_heading:
                                break
                        except Exception:
                            pass

                body_text = await page.locator("body").inner_text(timeout=5000)
                body_text = normalize_text(body_text)

                if not main_heading:
                    main_heading = extract_title_from_text(body_text)

                result = {
                    "listing_url": url,
                    "page_title": title,
                    "title_extracted": main_heading,
                    "exact_address": main_heading,
                    "postal_code": extract_postal_code(body_text),
                    "price_detail": extract_price(body_text),
                    "town_detail": extract_town(body_text),
                    "bedrooms_detail": extract_bedrooms(body_text),
                    "bathrooms_detail": extract_bathrooms(body_text),
                    "area_detail": extract_area(body_text),
                    "floor_detail": extract_floor(body_text),
                    "tenure_detail": extract_tenure(body_text),
                    "property_type_detail": extract_property_type(body_text),
                    "listing_id_detail": extract_listing_id(body_text),
                    "body_text_raw": body_text[:12000],
                    "error": None
                }

                print({
                    "address": result["exact_address"],
                    "price": result["price_detail"],
                    "town": result["town_detail"],
                    "beds": result["bedrooms_detail"],
                    "baths": result["bathrooms_detail"],
                    "area": result["area_detail"],
                    "floor": result["floor_detail"]
                })

                results.append(result)
                done_urls.add(url)

            except Exception as e:
                print("Error:", e)

                results.append({
                    "listing_url": url,
                    "page_title": None,
                    "title_extracted": None,
                    "exact_address": None,
                    "postal_code": None,
                    "price_detail": None,
                    "town_detail": None,
                    "bedrooms_detail": None,
                    "bathrooms_detail": None,
                    "area_detail": None,
                    "floor_detail": None,
                    "tenure_detail": None,
                    "property_type_detail": None,
                    "listing_id_detail": None,
                    "body_text_raw": None,
                    "error": str(e)
                })
                done_urls.add(url)

            if len(done_urls) % CHECKPOINT_EVERY == 0:
                temp_df = pd.DataFrame(results).drop_duplicates(subset=["listing_url"], keep="last")
                temp_df.to_csv(OUTPUT_FILE, index=False)
                print(f"Checkpoint saved. Total completed so far: {len(temp_df)}")

        await context.close()

    final_df = pd.DataFrame(results).drop_duplicates(subset=["listing_url"], keep="last")
    final_df.to_csv(OUTPUT_FILE, index=False)
    return final_df

# =========================================================
# RUN
# =========================================================
links_df = await collect_listing_links()

print("\nNow enriching collected listing links...")
enriched_full_df = await enrich_all_links(links_df)

print("\nFinished.")
print("Final dataframe shape:", enriched_full_df.shape)

display(
    enriched_full_df[[
        "listing_url",
        "exact_address",
        "postal_code",
        "price_detail",
        "town_detail",
        "bedrooms_detail",
        "bathrooms_detail",
        "area_detail",
        "floor_detail",
        "tenure_detail",
        "property_type_detail",
        "listing_id_detail",
        "error"
    ]].head(20)
)
# Out:
# ================================================================================
# Browser opened for search pages.
# If you see Cloudflare / cookie banner / 'Just a moment...', solve it manually.
# Waiting 10 seconds before starting...
# ================================================================================
#
# [Search page 1/3] Opening: https://www.propertyguru.com.sg/property-for-sale/1?__NA=true&hdbEstate=1&hdbEstate=10&hdbEstate=2&hdbEstate=20&hdbEstate=21&hdbEstate=22&hdbEstate=23&hdbEstate=24&hdbEstate=25&hdbEstate=26&hdbEstate=27&hdbEstate=28&hdbEstate=11&hdbEstate=3&hdbEstate=4&hdbEstate=5&hdbEstate=6&hdbEstate=7&hdbEstate=8&hdbEstate=9&hdbEstate=12&hdbEstate=13&hdbEstate=14&hdbEstate=15&hdbEstate=17&hdbEstate=18&hdbEstate=19&search=true&listingType=sale&isCommercial=false&locale=en
# Found 64 listing links. Added 64 new ones.
#
# [Search page 2/3] Opening: https://www.propertyguru.com.sg/property-for-sale/2?__NA=true&hdbEstate=1&hdbEstate=10&hdbEstate=2&hdbEstate=20&hdbEstate=21&hdbEstate=22&hdbEstate=23&hdbEstate=24&hdbEstate=25&hdbEstate=26&hdbEstate=27&hdbEstate=28&hdbEstate=11&hdbEstate=3&hdbEstate=4&hdbEstate=5&hdbEstate=6&hdbEstate=7&hdbEstate=8&hdbEstate=9&hdbEstate=12&hdbEstate=13&hdbEstate=14&hdbEstate=15&hdbEstate=17&hdbEstate=18&hdbEstate=19&search=true&listingType=sale&isCommercial=false&locale=en
# Found 60 listing links. Added 60 new ones.
#
# [Search page 3/3] Opening: https://www.propertyguru.com.sg/property-for-sale/3?__NA=true&hdbEstate=1&hdbEstate=10&hdbEstate=2&hdbEstate=20&hdbEstate=21&hdbEstate=22&hdbEstate=23&hdbEstate=24&hdbEstate=25&hdbEstate=26&hdbEstate=27&hdbEstate=28&hdbEstate=11&hdbEstate=3&hdbEstate=4&hdbEstate=5&hdbEstate=6&hdbEstate=7&hdbEstate=8&hdbEstate=9&hdbEstate=12&hdbEstate=13&hdbEstate=14&hdbEstate=15&hdbEstate=17&hdbEstate=18&hdbEstate=19&search=true&listingType=sale&isCommercial=false&locale=en
# Found 69 listing links. Added 69 new ones.
#
# Finished collecting listing links.
# Total unique listing URLs collected: 193
#
# Now enriching collected listing links...
# ================================================================================
# Browser opened.
# If you see Cloudflare / cookie banner / 'Just a moment...', solve it manually.
# Waiting 10 seconds before starting...
# ================================================================================
#
# [1/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-narra-residences-500087875
# Cloudflare detected. Solve it manually in the browser.
# {'address': 'Narra Residences', 'price': 'S$ 2,121,000', 'town': 'Ang Mo Kio', 'beds': '3', 'baths': '2', 'area': '1,001 sqft', 'floor': None}
#
# [2/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-narra-residences-500087875#media-floorPlans
# {'address': 'Narra Residences', 'price': 'S$ 2,121,000', 'town': 'Ang Mo Kio', 'beds': '3', 'baths': '2', 'area': '1,001 sqft', 'floor': None}
#
# [3/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-narra-residences-500087875#media-images
# {'address': 'Narra Residences', 'price': 'S$ 2,121,000', 'town': 'Ang Mo Kio', 'beds': '3', 'baths': '2', 'area': '1,001 sqft', 'floor': None}
#
# [4/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500059235
# {'address': 'Pinery Residences', 'price': 'S$ 3,325,000', 'town': 'Bedok', 'beds': '5', 'baths': '2', 'area': '1,389 sqft', 'floor': None}
#
# [5/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500059235#media-floorPlans
# {'address': 'Pinery Residences', 'price': 'S$ 3,325,000', 'town': 'Bedok', 'beds': '5', 'baths': '4', 'area': '1,389 sqft', 'floor': None}
#
# [6/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500059235#media-images
# {'address': 'Pinery Residences', 'price': 'S$ 3,325,000', 'town': 'Bedok', 'beds': '5', 'baths': '4', 'area': '1,389 sqft', 'floor': None}
#
# [7/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500078443
# {'address': 'Pinery Residences', 'price': 'S$ 1,660,000', 'town': 'Bedok', 'beds': '2', 'baths': '2', 'area': '700 sqft', 'floor': None}
#
# [8/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500078443#media-floorPlans
# {'address': 'Pinery Residences', 'price': 'S$ 1,660,000', 'town': 'Bedok', 'beds': '2', 'baths': '2', 'area': '700 sqft', 'floor': None}
#
# [9/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500078443#media-images
# {'address': 'Pinery Residences', 'price': 'S$ 1,660,000', 'town': 'Bedok', 'beds': '2', 'baths': '2', 'area': '700 sqft', 'floor': None}
#
# [10/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500078443#media-videos
# {'address': 'Pinery Residences', 'price': 'S$ 1,660,000', 'town': 'Bedok', 'beds': '2', 'baths': '2', 'area': '700 sqft', 'floor': None}
#
# [11/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500078443#media-virtualTours
# {'address': 'Pinery Residences', 'price': 'S$ 1,660,000', 'town': 'Bedok', 'beds': '2', 'baths': '2', 'area': '700 sqft', 'floor': None}
#
# [12/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500095685
# {'address': 'Pinery Residences', 'price': 'S$ 3,077,000', 'town': 'Bedok', 'beds': '4', 'baths': '3', 'area': '1,227 sqft', 'floor': None}
#
# [13/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500095685#media-floorPlans
# {'address': 'Pinery Residences', 'price': 'S$ 3,077,000', 'town': 'Bedok', 'beds': '4', 'baths': '3', 'area': '1,227 sqft', 'floor': None}
#
# [14/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-500095685#media-images
# {'address': 'Pinery Residences', 'price': 'S$ 3,077,000', 'town': 'Bedok', 'beds': '4', 'baths': '3', 'area': '1,227 sqft', 'floor': None}
#
# [15/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-60242911
# {'address': 'Pinery Residences', 'price': 'S$ 3,325,000', 'town': 'Bedok', 'beds': '4', 'baths': '4', 'area': '1,389 sqft', 'floor': None}
#
# [16/193] Opening: https://www.propertyguru.com.sg/listing/for-sale-pinery-residences-60242911#media-images
# {'address': 'Pinery Residences', 'price': 'S$ 3,325,000', 'town': 'Bedok', 'beds': '4', 'baths': '4', 'area': '1,389 sqft', 'floor': None}
#
# [17/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-102-jalan-rajah-500087252
# {'address': '102 Jalan Rajah', 'price': 'S$ 580,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '990 sqft', 'floor': 'Low floor'}
#
# [18/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-102-jalan-rajah-500087252#media-floorPlans
# {'address': '102 Jalan Rajah', 'price': 'S$ 580,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '990 sqft', 'floor': 'Low floor'}
#
# [19/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-102-jalan-rajah-500087252#media-images
# {'address': '102 Jalan Rajah', 'price': 'S$ 580,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '990 sqft', 'floor': 'Low floor'}
#
# [20/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-102-jalan-rajah-500087252#media-videos
# {'address': '102 Jalan Rajah', 'price': 'S$ 580,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '990 sqft', 'floor': 'Low floor'}
#
# [21/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-104-potong-pasir-avenue-1-500069474
# {'address': '104 Potong Pasir Avenue 1', 'price': 'S$ 618,000', 'town': 'Clementi', 'beds': '2', 'baths': '2', 'area': '797 sqft', 'floor': 'High Floor'}
#
# [22/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-104-potong-pasir-avenue-1-500069474#media-images
# {'address': '104 Potong Pasir Avenue 1', 'price': 'S$ 618,000', 'town': 'Clementi', 'beds': '2', 'baths': '2', 'area': '797 sqft', 'floor': 'High Floor'}
#
# [23/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-104-potong-pasir-avenue-1-500069474#media-videos
# {'address': '104 Potong Pasir Avenue 1', 'price': 'S$ 618,000', 'town': 'Clementi', 'beds': '2', 'baths': '2', 'area': '797 sqft', 'floor': 'High Floor'}
#
# [24/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-108c-mcnair-road-25292632
# {'address': '108C Mcnair Road', 'price': 'S$ 1,080,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,184 sqft', 'floor': None}
#
# [25/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-108c-mcnair-road-25292632#media-floorPlans
# {'address': '108C Mcnair Road', 'price': 'S$ 1,080,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,184 sqft', 'floor': None}
#
# [26/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-108c-mcnair-road-25292632#media-images
# {'address': '108C Mcnair Road', 'price': 'S$ 1,080,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,184 sqft', 'floor': None}
#
# [27/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-108c-mcnair-road-25292632#media-videos
# {'address': '108C Mcnair Road', 'price': 'S$ 1,080,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,184 sqft', 'floor': None}
#
# [28/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-112-mcnair-road-60214421
# {'address': '112 Mcnair Road', 'price': 'S$ 1,090,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,399 sqft', 'floor': 'high floor'}
#
# [29/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-112-mcnair-road-60214421#media-floorPlans
# {'address': '112 Mcnair Road', 'price': 'S$ 1,090,000', 'town': 'Clementi', 'beds': '2', 'baths': '2', 'area': '1,399 sqft', 'floor': 'high floor'}
#
# [30/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-112-mcnair-road-60214421#media-images
# {'address': '112 Mcnair Road', 'price': 'S$ 1,090,000', 'town': 'Clementi', 'beds': '2', 'baths': '2', 'area': '1,399 sqft', 'floor': 'high floor'}
#
# [31/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-112-mcnair-road-60214421#media-virtualTours
# {'address': '112 Mcnair Road', 'price': 'S$ 1,090,000', 'town': 'Clementi', 'beds': '2', 'baths': '2', 'area': '1,399 sqft', 'floor': 'high floor'}
#
# [32/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-117-serangoon-north-avenue-1-500038275
# {'address': '117 Serangoon North Avenue 1', 'price': 'S$ 728,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,302 sqft', 'floor': None}
#
# [33/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-117-serangoon-north-avenue-1-500038275#media-floorPlans
# {'address': '117 Serangoon North Avenue 1', 'price': 'S$ 728,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,302 sqft', 'floor': None}
#
# [34/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-117-serangoon-north-avenue-1-500038275#media-images
# {'address': '117 Serangoon North Avenue 1', 'price': 'S$ 728,000', 'town': 'Clementi', 'beds': '3', 'baths': '2', 'area': '1,302 sqft', 'floor': None}
#
# [35/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-131-cashew-road-500079530
# {'address': '131 Cashew Road', 'price': 'S$ 500,000', 'town': 'Bukit Panjang', 'beds': '2', 'baths': '2', 'area': '786 sqft', 'floor': 'High Floor'}
#
# [36/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-131-cashew-road-500079530#media-floorPlans
# {'address': '131 Cashew Road', 'price': 'S$ 500,000', 'town': 'Bukit Batok', 'beds': '2', 'baths': '2', 'area': '786 sqft', 'floor': 'High Floor'}
#
# [37/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-131-cashew-road-500079530#media-images
# Error: Mouse.move: Target page, context or browser has been closed
#
# [38/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-14-dover-close-east-500040733
# Error: Page.goto: Target page, context or browser has been closed
#
# [39/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-14-dover-close-east-500040733#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [40/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-14-dover-close-east-500040733#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [41/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-17-beach-road-500086697
# Error: Page.goto: Target page, context or browser has been closed
#
# [42/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-17-beach-road-500086697#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [43/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-17-beach-road-500086697#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [44/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-17-beach-road-60218568
# Error: Page.goto: Target page, context or browser has been closed
#
# [45/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-17-beach-road-60218568#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [46/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-17-beach-road-60218568#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [47/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-18-bedok-south-road-500059721
# Error: Page.goto: Target page, context or browser has been closed
#
# [48/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-18-bedok-south-road-500059721#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [49/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-18-bedok-south-road-500059721#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [50/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-18c-macpherson-residency-500092623
# Error: Page.goto: Target page, context or browser has been closed
# Checkpoint saved. Total completed so far: 50
#
# [51/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-18c-macpherson-residency-500092623#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [52/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-211-jurong-east-street-21-60217138
# Error: Page.goto: Target page, context or browser has been closed
#
# [53/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-211-jurong-east-street-21-60217138#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [54/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-211-jurong-east-street-21-60217138#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [55/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-216-bishan-street-23-500078973
# Error: Page.goto: Target page, context or browser has been closed
#
# [56/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-216-bishan-street-23-500078973#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [57/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-216-bishan-street-23-500078973#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [58/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-217-bishan-street-23-60027295
# Error: Page.goto: Target page, context or browser has been closed
#
# [59/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-217-bishan-street-23-60027295#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [60/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-217-bishan-street-23-60027295#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [61/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-217-bishan-street-23-60027295#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [62/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-217-bishan-street-23-60027295#media-virtualTours
# Error: Page.goto: Target page, context or browser has been closed
#
# [63/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-231-bishan-street-23-500092143
# Error: Page.goto: Target page, context or browser has been closed
#
# [64/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-231-bishan-street-23-500092143#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [65/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-231-bishan-street-23-500092143#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [66/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-235-bukit-batok-east-avenue-5-500081350
# Error: Page.goto: Target page, context or browser has been closed
#
# [67/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-235-bukit-batok-east-avenue-5-500081350#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [68/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-24-hougang-avenue-3-500066281
# Error: Page.goto: Target page, context or browser has been closed
#
# [69/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-24-hougang-avenue-3-500066281#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [70/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-24-hougang-avenue-3-500066281#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [71/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-269-bukit-batok-east-avenue-4-500063993
# Error: Page.goto: Target page, context or browser has been closed
#
# [72/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-269-bukit-batok-east-avenue-4-500063993#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [73/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-269-bukit-batok-east-avenue-4-500063993#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [74/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-269-bukit-batok-east-avenue-4-500063993#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [75/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-281-toh-guan-road-500093443
# Error: Page.goto: Target page, context or browser has been closed
#
# [76/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-281-toh-guan-road-500093443#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [77/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-281-toh-guan-road-500093443#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [78/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-285c-toh-guan-road-60041771
# Error: Page.goto: Target page, context or browser has been closed
#
# [79/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-285c-toh-guan-road-60041771#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [80/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-285c-toh-guan-road-60041771#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [81/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-3-saint-george-s-road-500037849
# Error: Page.goto: Target page, context or browser has been closed
#
# [82/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-3-saint-george-s-road-500037849#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [83/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-3-saint-george-s-road-500037849#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [84/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-308-clementi-avenue-4-500071707
# Error: Page.goto: Target page, context or browser has been closed
#
# [85/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-308-clementi-avenue-4-500071707#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [86/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-320-ubi-avenue-1-60214474
# Error: Page.goto: Target page, context or browser has been closed
#
# [87/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-320-ubi-avenue-1-60214474#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [88/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500094803
# Error: Page.goto: Target page, context or browser has been closed
#
# [89/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500094803#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [90/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500094803#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [91/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500094803#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [92/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500099348
# Error: Page.goto: Target page, context or browser has been closed
#
# [93/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500099348#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [94/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500099348#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [95/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-324-serangoon-avenue-3-500099348#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [96/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-333-ang-mo-kio-avenue-1-500040551
# Error: Page.goto: Target page, context or browser has been closed
#
# [97/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-333-ang-mo-kio-avenue-1-500040551#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [98/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-337-ang-mo-kio-avenue-1-500006443
# Error: Page.goto: Target page, context or browser has been closed
#
# [99/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-337-ang-mo-kio-avenue-1-500006443#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [100/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-337-ang-mo-kio-avenue-1-500006443#media-videos
# Error: Page.goto: Target page, context or browser has been closed
# Checkpoint saved. Total completed so far: 100
#
# [101/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-35-marine-crescent-500047552
# Error: Page.goto: Target page, context or browser has been closed
#
# [102/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-35-marine-crescent-500047552#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [103/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-35-marine-crescent-500047552#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [104/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-383-bukit-batok-west-avenue-5-500086733
# Error: Page.goto: Target page, context or browser has been closed
#
# [105/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-383-bukit-batok-west-avenue-5-500086733#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [106/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-383-bukit-batok-west-avenue-5-500086733#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [107/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-383-bukit-batok-west-avenue-5-500086733#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [108/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-383-bukit-batok-west-avenue-5-500086733#media-virtualTours
# Error: Page.goto: Target page, context or browser has been closed
#
# [109/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-41-cambridge-road-500074709
# Error: Page.goto: Target page, context or browser has been closed
#
# [110/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-41-cambridge-road-500074709#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [111/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-41-cambridge-road-500074709#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [112/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-425-canberra-road-25470637
# Error: Page.goto: Target page, context or browser has been closed
#
# [113/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-425-canberra-road-25470637#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [114/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-425-canberra-road-25470637#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [115/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-429-clementi-avenue-3-500046834
# Error: Page.goto: Target page, context or browser has been closed
#
# [116/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-429-clementi-avenue-3-500046834#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [117/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-429-clementi-avenue-3-500046834#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [118/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-43-bedok-south-road-500043474
# Error: Page.goto: Target page, context or browser has been closed
#
# [119/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-43-bedok-south-road-500043474#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [120/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-439-ang-mo-kio-avenue-10-500047893
# Error: Page.goto: Target page, context or browser has been closed
#
# [121/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-439-ang-mo-kio-avenue-10-500047893#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [122/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-439-ang-mo-kio-avenue-10-500047893#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [123/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-439-ang-mo-kio-avenue-10-500047893#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [124/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-489-admiralty-link-60208421
# Error: Page.goto: Target page, context or browser has been closed
#
# [125/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-489-admiralty-link-60208421#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [126/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-489-admiralty-link-60208421#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [127/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-49-strathmore-avenue-500040522
# Error: Page.goto: Target page, context or browser has been closed
#
# [128/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-49-strathmore-avenue-500040522#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [129/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-49-strathmore-avenue-500040522#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [130/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-49-strathmore-avenue-500040522#media-virtualTours
# Error: Page.goto: Target page, context or browser has been closed
#
# [131/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-5-ghim-moh-road-500065407
# Error: Page.goto: Target page, context or browser has been closed
#
# [132/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-5-ghim-moh-road-500065407#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [133/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-5-ghim-moh-road-500065407#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [134/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-504-ang-mo-kio-avenue-8-500080721
# Error: Page.goto: Target page, context or browser has been closed
#
# [135/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-504-ang-mo-kio-avenue-8-500080721#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [136/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-504-ang-mo-kio-avenue-8-500080721#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [137/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-53-strathmore-avenue-25578516
# Error: Page.goto: Target page, context or browser has been closed
#
# [138/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-53-strathmore-avenue-25578516#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [139/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-53-strathmore-avenue-25578516#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [140/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-53-strathmore-avenue-25578516#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [141/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-53-strathmore-avenue-25578516#media-virtualTours
# Error: Page.goto: Target page, context or browser has been closed
#
# [142/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-539-serangoon-north-avenue-4-500084644
# Error: Page.goto: Target page, context or browser has been closed
#
# [143/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-539-serangoon-north-avenue-4-500084644#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [144/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-539-serangoon-north-avenue-4-500084644#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [145/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-539-serangoon-north-avenue-4-500084644#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [146/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-539-serangoon-north-avenue-4-500094793
# Error: Page.goto: Target page, context or browser has been closed
#
# [147/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-539-serangoon-north-avenue-4-500094793#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [148/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-539-serangoon-north-avenue-4-500094793#media-virtualTours
# Error: Page.goto: Target page, context or browser has been closed
#
# [149/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-588d-ang-mo-kio-street-52-500066200
# Error: Page.goto: Target page, context or browser has been closed
#
# [150/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-588d-ang-mo-kio-street-52-500066200#media-images
# Error: Page.goto: Target page, context or browser has been closed
# Checkpoint saved. Total completed so far: 150
#
# [151/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-588d-ang-mo-kio-street-52-500066200#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [152/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-629-hougang-avenue-8-500083206
# Error: Page.goto: Target page, context or browser has been closed
#
# [153/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-629-hougang-avenue-8-500083206#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [154/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-629-hougang-avenue-8-500083206#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [155/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-636b-senja-parc-view-500031959
# Error: Page.goto: Target page, context or browser has been closed
#
# [156/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-636b-senja-parc-view-500031959#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [157/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-636b-senja-parc-view-500031959#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [158/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-636b-senja-parc-view-500031959#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [159/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-643-ang-mo-kio-avenue-5-500030514
# Error: Page.goto: Target page, context or browser has been closed
#
# [160/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-643-ang-mo-kio-avenue-5-500030514#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [161/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-643-ang-mo-kio-avenue-5-500030514#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [162/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-643-ang-mo-kio-avenue-5-500030514#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [163/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-702-west-coast-road-500097572
# Error: Page.goto: Target page, context or browser has been closed
#
# [164/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-702-west-coast-road-500097572#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [165/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-747c-bedok-reservoir-crescent-500043579
# Error: Page.goto: Target page, context or browser has been closed
#
# [166/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-747c-bedok-reservoir-crescent-500043579#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [167/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-747c-bedok-reservoir-crescent-500043579#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [168/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-81-commonwealth-close-23663635
# Error: Page.goto: Target page, context or browser has been closed
#
# [169/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-81-commonwealth-close-23663635#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [170/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-81-commonwealth-close-23663635#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [171/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-92b-telok-blangah-street-31-500054450
# Error: Page.goto: Target page, context or browser has been closed
#
# [172/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-92b-telok-blangah-street-31-500054450#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [173/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-92b-telok-blangah-street-31-500054450#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [174/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-93-whampoa-drive-500053006
# Error: Page.goto: Target page, context or browser has been closed
#
# [175/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-93-whampoa-drive-500053006#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [176/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-93-whampoa-drive-500053006#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [177/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-94-dawson-road-500033976
# Error: Page.goto: Target page, context or browser has been closed
#
# [178/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-94-dawson-road-500033976#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [179/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-94-dawson-road-500033976#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [180/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-94-dawson-road-500042103
# Error: Page.goto: Target page, context or browser has been closed
#
# [181/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-94-dawson-road-500042103#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [182/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-94-dawson-road-500042103#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [183/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-94-dawson-road-500042103#media-virtualTours
# Error: Page.goto: Target page, context or browser has been closed
#
# [184/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-956-hougang-street-91-500093435
# Error: Page.goto: Target page, context or browser has been closed
#
# [185/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-956-hougang-street-91-500093435#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [186/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-956-hougang-street-91-500093435#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [187/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-96-bedok-north-avenue-4-500043548
# Error: Page.goto: Target page, context or browser has been closed
#
# [188/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-96-bedok-north-avenue-4-500043548#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [189/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-96-bedok-north-avenue-4-500043548#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# [190/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-move-in-ready-newly-mop-city-fringe-hdb-great-deal-500092806
# Error: Page.goto: Target page, context or browser has been closed
#
# [191/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-move-in-ready-newly-mop-city-fringe-hdb-great-deal-500092806#media-floorPlans
# Error: Page.goto: Target page, context or browser has been closed
#
# [192/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-move-in-ready-newly-mop-city-fringe-hdb-great-deal-500092806#media-images
# Error: Page.goto: Target page, context or browser has been closed
#
# [193/193] Opening: https://www.propertyguru.com.sg/listing/hdb-for-sale-move-in-ready-newly-mop-city-fringe-hdb-great-deal-500092806#media-videos
# Error: Page.goto: Target page, context or browser has been closed
#
# Finished.
# Final dataframe shape: (193, 16)
#                                           listing_url      exact_address  \
# 0   https://www.propertyguru.com.sg/listing/for-sa...   Narra Residences
# 1   https://www.propertyguru.com.sg/listing/for-sa...   Narra Residences
# 2   https://www.propertyguru.com.sg/listing/for-sa...   Narra Residences
# 3   https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 4   https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 5   https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 6   https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 7   https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 8   https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 9   https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 10  https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 11  https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 12  https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 13  https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 14  https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 15  https://www.propertyguru.com.sg/listing/for-sa...  Pinery Residences
# 16  https://www.propertyguru.com.sg/listing/hdb-fo...    102 Jalan Rajah
# 17  https://www.propertyguru.com.sg/listing/hdb-fo...    102 Jalan Rajah
# 18  https://www.propertyguru.com.sg/listing/hdb-fo...    102 Jalan Rajah
# 19  https://www.propertyguru.com.sg/listing/hdb-fo...    102 Jalan Rajah
#
#    postal_code  price_detail town_detail bedrooms_detail bathrooms_detail  \
# 0         None  S$ 2,121,000  Ang Mo Kio               3                2
# 1         None  S$ 2,121,000  Ang Mo Kio               3                2
# 2         None  S$ 2,121,000  Ang Mo Kio               3                2
# 3         None  S$ 3,325,000       Bedok               5                2
# 4         None  S$ 3,325,000       Bedok               5                4
# 5         None  S$ 3,325,000       Bedok               5                4
# 6         None  S$ 1,660,000       Bedok               2                2
# 7         None  S$ 1,660,000       Bedok               2                2
# 8         None  S$ 1,660,000       Bedok               2                2
# 9         None  S$ 1,660,000       Bedok               2                2
# 10        None  S$ 1,660,000       Bedok               2                2
# 11        None  S$ 3,077,000       Bedok               4                3
# 12        None  S$ 3,077,000       Bedok               4                3
# 13        None  S$ 3,077,000       Bedok               4                3
# 14        None  S$ 3,325,000       Bedok               4                4
# 15        None  S$ 3,325,000       Bedok               4                4
# 16        None    S$ 580,000    Clementi               3                2
# 17        None    S$ 580,000    Clementi               3                2
# 18        None    S$ 580,000    Clementi               3                2
# 19        None    S$ 580,000    Clementi               3                2
#
#    area_detail floor_detail tenure_detail property_type_detail  \
# 0   1,001 sqft          NaN          None                  HDB
# 1   1,001 sqft          NaN          None                  HDB
# 2   1,001 sqft          NaN          None                  HDB
# 3   1,389 sqft          NaN          None                  HDB
# 4   1,389 sqft          NaN          None                  HDB
# 5   1,389 sqft          NaN          None                  HDB
# 6     700 sqft          NaN          None                  HDB
# 7     700 sqft          NaN          None                  HDB
# 8     700 sqft          NaN          None                  HDB
# 9     700 sqft          NaN          None                  HDB
# 10    700 sqft          NaN          None                  HDB
# 11  1,227 sqft          NaN          None                  HDB
# 12  1,227 sqft          NaN          None                  HDB
# 13  1,227 sqft          NaN          None                  HDB
# 14  1,389 sqft          NaN          None                  HDB
# 15  1,389 sqft          NaN          None                  HDB
# 16    990 sqft    Low floor          None                  HDB
# 17    990 sqft    Low floor          None                  HDB
# 18    990 sqft    Low floor          None                  HDB
# 19    990 sqft    Low floor          None                  HDB
#
#    listing_id_detail error
# 0               None   NaN
# 1               None   NaN
# 2               None   NaN
# 3               None   NaN
# 4               None   NaN
# 5               None   NaN
# 6               None   NaN
# 7               None   NaN
# 8               None   NaN
# 9               None   NaN
# 10              None   NaN
# 11              None   NaN
# 12              None   NaN
# 13              None   NaN
# 14              None   NaN
# 15              None   NaN
# 16              None   NaN
# 17              None   NaN
# 18              None   NaN
# 19              None   NaN
