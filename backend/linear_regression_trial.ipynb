# %% [markdown]
# ### Predicting HDB Prices with Multivariate Linear Regression
#
# Having collected the data, wrangled it together, done exploratory data analysis, we will now begin to model the data to predict HDB prices.
#
# In this notebook, we will be using Multivariate Linear Regression for prediction. This is a 'quick and dirty' model which is fast and reliable, with easy interpretation of model coefficients.
#
# The final selling price of a HDB isn’t just based on one thing - how big the HDB is, but also factors like the number of bedrooms, the age of the HDB, and maybe even how close it is to the city center. Basically all the data which we have wrangled together. Multivariate linear regression is a fancy way of saying we use all these different bits of information - size, bedrooms, age, location - to make a good guess at the HDB price. Each factor has its own weight in the equation, kind of like ingredients in a recipe, each contributing differently to the final price.
#
# #### **Objective:** Predict HDB Price (dependent variable) using multiple independent variables (collected data).
# - **Equation for Multivariate Linear Regression**
#   - Y = β₀ + β₁X₁ + β₂X₂ + ... + βₖXₖ + ε
#     - Y: Dependent variable (HDB Price)
#     - β₀: Y-intercept
#     - β₁, β₂, ... , βₖ: Coefficients for independent variables X₁, X₂, ..., Xₖ (the weights)
#     - ε: Error term
# - **Assumption**
#   - Assumes a linear relationship between dependent and independent variables. Involves multiple independent variables (β).
#   - Assumes independence of errors, constant variance of errors (homoscedasticity), and normally distributed errors.
# - **Parameters**
#   - Coefficients (β) are estimated to minimize the sum of squared residuals. This is the loss function, used to create the line of best fit.
# - **Goodness of Fit**: Measured by metrics like R-squared, Mean Squared Error (MSE), Mean Absolute Percentage Error (MAPE)
#   - In this notebook we will use R2 and MAE.
# - **Interpretation**
#   - Coefficients indicate the impact/weight of each independent variable on the dependent variable.
# - **Variants**
#   - Multiple variations exist, including ridge and lasso regression for regularization.

# %% [markdown]
# #### Load Libraries

# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Train Test Split
from sklearn.model_selection import train_test_split, cross_validate

# Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# Modelling
from sklearn.linear_model import LinearRegression

# Model Evaluation
from sklearn.metrics import mean_absolute_error, r2_score
import scipy.stats as stats

# Saving Model
import pickle

import os

# %% [markdown]
# #### Load data into DataFrame and Remove Unwanted Columns

# %%
# Navigate to your project
os.chdir('/workspaces/DSE3101-Project')

# Verify you're in the right place
print("Current directory:", os.getcwd())
print("Contents:", os.listdir('.'))

# Navigate to data/raw folder
os.chdir('data/raw')
# Out:
# Current directory: /workspaces/DSE3101-Project
# Contents: ['docs', '.git', 'notebooks', '.DS_Store', 'models', 'frontend', 'requirements.txt', '.gitignore', '.vscode', 'backend', 'data', 'onemap_all_themes_full.json', 'README.md', 'onemap_all_themes_raw.txt']

# %%
hdb_df = pd.read_csv('HDB_full_resale_info.csv.gz')
print(hdb_df.info())

# Put all columns to be deleted into a list
drop_cols = ['block', 'street_name','address','sold_year_month']

# Drop columns
hdb_df = hdb_df.drop(columns=drop_cols, errors='ignore')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 259143 entries, 0 to 259142
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   town                               259143 non-null  str
#  1   flat_type                          259143 non-null  str
#  2   block                              259143 non-null  str
#  3   street_name                        259143 non-null  str
#  4   storey_range                       259143 non-null  str
#  5   floor_area_sqm                     259143 non-null  float64
#  6   flat_model                         259143 non-null  str
#  7   lease_commence_date                259143 non-null  int64
#  8   resale_price                       259143 non-null  float64
#  9   remaining_lease                    259143 non-null  int64
#  10  sold_year                          259143 non-null  int64
#  11  address                            259143 non-null  str
#  12  max_floor_lvl                      259143 non-null  int64
#  13  storey_mid                         259143 non-null  float64
#  14  storey_category                    259143 non-null  str
#  15  region                             259143 non-null  str
#  16  is_mature_estate                   259143 non-null  int64
#  17  latitude                           259143 non-null  float64
#  18  longitude                          259143 non-null  float64
#  19  matched_address                    259143 non-null  str
#  20  status                             259143 non-null  str
#  21  nearest_mrt_name                   259143 non-null  str
#  22  nearest_mrt_distance_m             259143 non-null  float64
#  23  nearest_clinic_name                259143 non-null  str
#  24  nearest_clinic_distance_m          259143 non-null  float64
#  25  nearest_park_name                  259143 non-null  str
#  26  nearest_park_distance_m            259143 non-null  float64
#  27  nearest_community_club_name        259143 non-null  str
#  28  nearest_community_club_distance_m  259143 non-null  float64
#  29  nearest_hawker_name                259143 non-null  str
#  30  nearest_hawker_distance_m          259143 non-null  float64
#  31  num_mrt_within_1000m               259143 non-null  int64
#  32  num_clinic_within_1000m            259143 non-null  int64
#  33  num_park_within_1000m              259143 non-null  int64
#  34  num_community_club_within_1000m    259143 non-null  int64
#  35  num_hawker_within_1000m            259143 non-null  int64
#  36  num_amenities_within_1000m         259143 non-null  int64
# dtypes: float64(10), int64(11), str(16)
# memory usage: 73.2 MB
# None

# %% [markdown]
# #### Prepare Data for Pipeline and Train Test Split
# ##### Check for Correlation and Remove Highly Correlated Columns
# Removing highly correlated columns makes the model simpler, more accurate, easier to interpret, and more reliable. Why?
#   - **Avoid Redundancy**
#     - Highly correlated columns provide similar information.
#     - Keeping both is like hearing the same thing twice.
#   - **Improve Model Accuracy**
#     - Linear regression assumes each column (feature) brings unique information.
#     - When columns are too similar (highly correlated), it confuses the model, leading to less accurate predictions.
#   - **Prevent Multicollinearity**
#     - This is a big word but it just means when columns are highly correlated, they can mess up the way the model understands how important each column is.
#     - This can make it hard to figure out which column really impacts the outcome.
#   - **Simpler Model**
#     - Removing highly correlated columns simplifies the model.
#     - A simpler model is usually better because it's easier to understand and explain.
#   - **Better Generalization**
#     - Simplified models with less redundancy often perform better on new, unseen data.
#     - This is because they focus on the most relevant information.
#   - **Stable Estimates**
#     - Highly correlated columns can make the model's estimates (like how much a change in one column will change the outcome) unstable and unreliable.
#     - Removing them helps stabilize these estimates.

# %%
# Calculate the correlation matrix
correlation_matrix = hdb_df.select_dtypes(include=np.number).corr()

# Correlation coefficients
plt.figure(figsize=(16, 9))
heatmap = sns.heatmap(correlation_matrix, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);

# %%
# Threshold for high correlation
threshold = 0.8

# Create empty list to populate
high_correlation_pairs = []

# Double for loop to get value pairs
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            # Get indexes of columns
            col_pair = (correlation_matrix.columns[i], correlation_matrix.columns[j])
            # Append to empty list
            high_correlation_pairs.append(col_pair)

# Print out the pairs of highly correlated columns
for pair in high_correlation_pairs:
    print(pair)
# Out:
# ('remaining_lease', 'lease_commence_date')
# ('num_amenities_within_1000m', 'num_clinic_within_1000m')

# %% [markdown]
# Columns to exclude:
# - 'lease_commence_date'
# - 'num_clinic_within_1000m'

# %%
drop_cols = ['lease_commence_date','num_clinic_within_1000m']

hdb_df = hdb_df.drop(columns=drop_cols)

# %%
# Calculate the correlation matrix
correlation_matrix = hdb_df.select_dtypes(include=np.number).corr()

# Correlation coefficients
plt.figure(figsize=(16, 9))
heatmap = sns.heatmap(correlation_matrix, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# #### Visualizing Resale Price Against Other Numeric Columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get a sample of dataset as full DF takes quite a while
temp = hdb_df.sample(100000, random_state=42)

# Get list of numeric columns and select column to plot against
column_of_interest = 'resale_price'
other_columns = temp.select_dtypes(include=['int64', 'float64']).columns.drop(column_of_interest)

# Number of subplot columns
n_cols = 5

# Ceiling division so there are enough subplot rows
n_rows = (len(other_columns) + n_cols - 1) // n_cols

# Create figure with subplots
fig, axs = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(4 * n_cols, 4 * n_rows))

# Flatten axes array for easy looping
axs = axs.flatten()

# Loop through columns and create regplot
for i, col in enumerate(other_columns):
    sns.regplot(
        data=temp,
        x=col,
        y=column_of_interest,
        ax=axs[i],
        ci=99,
        marker="x",
        color=".3",
        line_kws={"color": "r"}
    )
    axs[i].set_title(f'{col} vs {column_of_interest}')

# Hide unused subplots
for i in range(len(other_columns), len(axs)):
    axs[i].set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Create lists of the categorical and numerical columns allowing them to be treated differently
cat_cols = hdb_df.select_dtypes(include=['object']).columns
# Out:
# /tmp/ipykernel_44045/2948035398.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = hdb_df.select_dtypes(include=['object']).columns

# %%
# Create new list of numeric columns, removing resale_price from columns to scale
num_cols_scale = ['floor_area_sqm',
 'sold_year',
 'remaining_lease',
 'max_floor_lvl']

# %%
# Select target column
target_col = 'resale_price'

# Ready X and y
X = hdb_df.loc[:, ~hdb_df.columns.isin([target_col])]
y = hdb_df[target_col]

# Split the data, 80-20 split with a random state included for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 54)

# %% [markdown]
# #### Creating a Pipeline
# Pipelines are essentially the backbone of efficient and effective data modeling, ensuring a streamlined, consistent, and flexible approach.
#
#  - Streamlining Processes
#    - Pipelines allow the combination of various steps like data preprocessing, feature extraction, and model training into one cohesive process.
#  - Consistency and Reproducibility
#     - They ensure consistent application of preprocessing and modeling steps for reliable results.
#  - Ease of Modification
#     - Pipelines allow for easy alterations or replacements of individual components without needing to redo the entire process.
#  - Avoiding Data Leakage
#      - They prevent data leakage during cross-validation by properly managing data preprocessing steps.
#  - Simplifying Code
#      - Pipelines contribute to more organized and readable code, making the data modeling process cleaner and more manageable.
#  - Model Validation and Parameter Tuning
#      - They work well with grid search and cross-validation for effective model optimization and validation.
#  - Deployment Ready
#      - Pipelines simplify the deployment process as they encapsulate all necessary steps in a model's development.
#  - Flexibility
#      - They are versatile, accommodating various data transformations and modeling techniques.

# %% [markdown]
# #### Preprocessing Pipeline

# %% [markdown]
# Feature scaling is important for methods that apply a regularization penalty like Ridge or Lasso regression as we are doing here.
#
# The penalty applied is sum-of-squares in Ridge and sum-of-absolute values in Lasso. If features are on different scales, the regularization does not treat all features equally. Hence, scaling ensures that the regularization term is applied uniformly across all features.
#
# Also, when features are on the same scale, we can more meaningfully compare the magnitude of coefficients to determine which features have more impact on the outcome.
#
# However, in some cases, you might decide not to scale features - if the scale of the features is relevant to the problem (eg: a feature is bounded between 0 and 100 by definition), scaling may not be necessary and might even be misleading.

# %%
# Create instances of OneHotEncoder
cat_transformer = OneHotEncoder(drop='first', handle_unknown='ignore')

# Create pipeline of two scalers for numeric data
num_transformer = make_pipeline(RobustScaler(), MinMaxScaler())

# Create a final to apply transformations to subsets of columns
prepoc = make_column_transformer(
    (cat_transformer, cat_cols),
    (num_transformer, num_cols_scale)
)

# View Pipeline
prepoc
# Out:
# ColumnTransformer(transformers=[('onehotencoder',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  Index(['town', 'flat_type', 'storey_range', 'flat_model', 'storey_category',
#        'region', 'matched_address', 'status', 'nearest_mrt_name',
#        'nearest_clinic_name', 'nearest_park_name',
#        'nearest_community_club_name', 'nearest_hawker_name'],
#       dtype='str')),
#                                 ('pipeline',
#                                  Pipeline(steps=[('robustscaler',
#                                                   RobustScaler()),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler())]),
#                                  ['floor_area_sqm', 'sold_year',
#                                   'remaining_lease', 'max_floor_lvl'])])

# %%
# Process X & y with pipeline
X_train_processed = prepoc.fit_transform(X_train)
X_test_processed = prepoc.transform(X_test)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:261: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(msg, UserWarning)

# %%
# See what's in column 6
print("Train unique:", X_train.iloc[:, 6].unique())
print("Test unique:",  X_test.iloc[:, 6].unique())
print("Unknowns:", set(X_test.iloc[:, 6]) - set(X_train.iloc[:, 6]))
# Out:
# Train unique: [2023 2017 2021 2024 2019 2025 2020 2022 2018 2016 2015 2026]
# Test unique: [2022 2015 2018 2019 2024 2016 2023 2020 2017 2021 2025 2026]
# Unknowns: set()

# %%
# Check to see if it worked
print("Number of columns originally:", X.shape[1])
print("Number of columns after preprocessing:",X_train_processed.shape[1])
# Out:
# Number of columns originally: 31
# Number of columns after preprocessing: 10850

# %% [markdown]
# #### Creating a Base Multivariate Linear Regression Model & Evaluation

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Instantiate the model
linear_model = LinearRegression()

# Define multiple scoring metrics (added RMSE + MAPE)
scoring = [
    'r2', 
    'neg_mean_absolute_error',
    'neg_mean_squared_error',           # For RMSE  
    'neg_mean_absolute_percentage_error' # For MAPE
]

# Get the cross validation scores
scores = cross_validate(
    linear_model, 
    X_train_processed, 
    y_train, 
    cv=5, 
    scoring=scoring, 
    return_train_score=False
)

# Calculate and round means
train_r2_mean = round(scores['test_r2'].mean(), 2)
train_mae_mean = round(-(scores['test_neg_mean_absolute_error'].mean()), 2)
train_rmse_mean = round(np.sqrt(-(scores['test_neg_mean_squared_error'].mean())), 2)
train_mape_mean = round(-(scores['test_neg_mean_absolute_percentage_error'].mean()) * 100, 2)

# Print all scores
print("Training R² score =", train_r2_mean)
print("Training MAE =", train_mae_mean) 
print("Training RMSE =", train_rmse_mean)
print("Training MAPE (%) =", train_mape_mean)

# View scores dictionary (unchanged)
scores
# Out:
# Training R² score = 0.91
# Training MAE = 42148.64
# Training RMSE = 54466.07
# Training MAPE (%) = 8.98
# {'fit_time': array([11.97266197,  7.5202949 ,  6.79322839,  7.47435951,  6.90138245]),
#  'score_time': array([0.00486255, 0.00404859, 0.00389981, 0.00405908, 0.0038352 ]),
#  'test_r2': array([0.91100987, 0.91258389, 0.9136063 , 0.91150867, 0.91170141]),
#  'test_neg_mean_absolute_error': array([-42119.03271356, -42121.60743961, -42107.05582818, -42204.98690013,
#         -42190.50164153]),
#  'test_neg_mean_squared_error': array([-2.96914000e+09, -2.96855015e+09, -2.95885476e+09, -2.99191871e+09,
#         -2.94429993e+09]),
#  'test_neg_mean_absolute_percentage_error': array([-0.09001248, -0.0895567 , -0.08965995, -0.0896658 , -0.09003148])}

# %%
import numpy as np

# Get rounded scores stored in variables
train_base_r2_mean = round(scores['test_r2'].mean(), 2)
train_base_mae_mean = round(-(scores['test_neg_mean_absolute_error'].mean()), 2)
train_base_rmse_mean = round(np.sqrt(-(scores['test_neg_mean_squared_error'].mean())), 2)
train_base_mape_mean = round(-(scores['test_neg_mean_absolute_percentage_error'].mean()) * 100, 2)

# Print scores to assess
print("Training R² score =", train_base_r2_mean)
print("Training MAE =", train_base_mae_mean)
print("Training RMSE =", train_base_rmse_mean)
print("Training MAPE (%) =", train_base_mape_mean)
# Out:
# Training R² score = 0.91
# Training MAE = 42148.64
# Training RMSE = 54466.07
# Training MAPE (%) = 8.98

# %% [markdown]
# **Training R² Score = 0.91**
#
# - R² measures the proportion of variance in the dependent variable explained by the model.
# - A score of 0.91 indicates that 91% of the variability in HDB prices is accounted for by the model, which is generally considered a strong fit.
# - That said, a high R² alone does not guarantee model quality — it neither confirms that the model is appropriate nor that its predictions are accurate.
#
# **Training Mean Absolute Error (MAE) = $42,148.64**
#
# - MAE represents the average absolute difference between predicted and actual values, regardless of direction.
# - Here, the model's predictions deviate by an average of $42,148.64. Given that HDB flats average around $500,000, this translates to roughly a 10% error — a meaningful margin that should be considered when evaluating the model's practical usefulness.

# %%
# Fitting model on data.
linear_model.fit(X_train_processed, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
import numpy as np

# Predict y with fitted model
y_pred = linear_model.predict(X_test_processed)

# Calculate test set metrics (matching CV metrics)
test_base_mae_mean = round(mean_absolute_error(y_test, y_pred), 2)
test_base_rmse_mean = round(np.sqrt(mean_squared_error(y_test, y_pred)), 2)
test_base_r2_mean = round(r2_score(y_test, y_pred), 2)
test_base_mape_mean = round(-(scores['test_neg_mean_absolute_percentage_error'].mean()) * 100, 2)

# Print test scores (matching training format)
print("Testing R² score =", test_base_r2_mean)
print("Testing MAE =", test_base_mae_mean)
print("Testing RMSE =", test_base_rmse_mean)
print("Testing MAPE (%) =", test_base_mape_mean)
# Out:
# Testing R² score = 0.91
# Testing MAE = 42186.19
# Testing RMSE = 54495.0
# Testing MAPE (%) = 8.98

# %% [markdown]
# **Testing R² Score = 0.91**
#
# - The testing R² mirrors the training score, indicating the model generalizes well to unseen data. - This consistency between training and testing performance is a strong indicator of a robust, well-fitted model.
#
# **Testing MAE = $42,186.19**
#
# - The marginal increase in MAE from training ($42,148.64) to testing ($42,186.19) is negligible, suggesting the model is not overfitting and maintains reliable predictive performance on new data.
#
# **Overall**
#
# - The close alignment between training and testing metrics — both in R² and MAE — reflects a model that is consistent, well-generalized, and not merely memorizing the training data.
# - The high R² demonstrates strong explanatory power, while the MAE provides a practical sense of the average prediction error in dollar terms.

# %% [markdown]
# #### Taking a look at the Feature Coefficients

# %%
# To Get importance of features in a DF:
# Get feature names
feature_names = prepoc.get_feature_names_out()

# Get coefficients
coefficients = linear_model.coef_

# Create empty Dictionary
feature_coefficients = {}

# For loop to print coefficient and put them into dict
for feature, coef in zip(feature_names, coefficients):
    print(f"{feature}: {coef}")
    feature_coefficients[feature] = coef

# Include intercept in the dict
print(f"intercept: {linear_model.intercept_}")
feature_coefficients["intercept"] = linear_model.intercept_
# Out:
# onehotencoder__town_BEDOK: 66239.82116876089
# onehotencoder__town_BISHAN: 23081.27010398553
# onehotencoder__town_BUKIT BATOK: -33028.48002067243
# onehotencoder__town_BUKIT MERAH: -2233.9817968674365
# onehotencoder__town_BUKIT PANJANG: -58118.92027456763
# onehotencoder__town_BUKIT TIMAH: 55416.61357853023
# onehotencoder__town_CENTRAL AREA: 42239.63436545587
# onehotencoder__town_CHOA CHU KANG: -83200.6015392062
# onehotencoder__town_CLEMENTI: 53583.17129647277
# onehotencoder__town_GEYLANG: -33205.16458647885
# onehotencoder__town_HOUGANG: -16871.35712572612
# onehotencoder__town_JURONG EAST: -7795.776646365626
# onehotencoder__town_JURONG WEST: -26372.976414590383
# onehotencoder__town_KALLANG/WHAMPOA: -21172.38524465037
# onehotencoder__town_MARINE PARADE: 29412.79129843027
# onehotencoder__town_PASIR RIS: -48909.362304714356
# onehotencoder__town_PUNGGOL: -72167.12939269537
# onehotencoder__town_QUEENSTOWN: 44890.331362817036
# onehotencoder__town_SEMBAWANG: -36022.12556085368
# onehotencoder__town_SENGKANG: -79816.680857695
# onehotencoder__town_SERANGOON: 21613.48720345039
# onehotencoder__town_TAMPINES: 14560.12138583891
# onehotencoder__town_TOA PAYOH: -26017.93355580153
# onehotencoder__town_WOODLANDS: -57801.68031376726
# onehotencoder__town_YISHUN: -10494.003562492628
# onehotencoder__flat_type_2 ROOM: -87319.75341373649
# onehotencoder__flat_type_3 ROOM: -47528.25751097188
# onehotencoder__flat_type_4 ROOM: -5863.384448401816
# onehotencoder__flat_type_5 ROOM: 33837.72353071689
# onehotencoder__flat_type_EXECUTIVE: 61317.88109046462
# onehotencoder__flat_type_MULTI-GENERATION: 76330.21877923148
# onehotencoder__storey_range_04 TO 06: 17989.401891641195
# onehotencoder__storey_range_07 TO 09: -42211.44729435293
# onehotencoder__storey_range_10 TO 12: -28696.827027388492
# onehotencoder__storey_range_13 TO 15: -19108.11332558279
# onehotencoder__storey_range_16 TO 18: -54482.8563469668
# onehotencoder__storey_range_19 TO 21: -40622.32266939383
# onehotencoder__storey_range_22 TO 24: -33193.49159810483
# onehotencoder__storey_range_25 TO 27: -23689.68534987252
# onehotencoder__storey_range_28 TO 30: -6940.862753939803
# onehotencoder__storey_range_31 TO 33: 1694.5725484759485
# onehotencoder__storey_range_34 TO 36: 9365.716578715032
# onehotencoder__storey_range_37 TO 39: 18889.157120032873
# onehotencoder__storey_range_40 TO 42: 49402.957398302155
# onehotencoder__storey_range_43 TO 45: 82958.84300865742
# onehotencoder__storey_range_46 TO 48: 71727.17273344279
# onehotencoder__storey_range_49 TO 51: 132761.67879891532
# onehotencoder__flat_model_3Gen: 14610.54514655923
# onehotencoder__flat_model_Adjoined flat: 84710.05350608227
# onehotencoder__flat_model_Apartment: 69122.89542598312
# onehotencoder__flat_model_DBSS: 113523.78121656379
# onehotencoder__flat_model_Executive Maisonette: 118719.30396095639
# onehotencoder__flat_model_Improved: 15279.071183212605
# onehotencoder__flat_model_Maisonette: 83084.21315845472
# onehotencoder__flat_model_Model A: 16392.31174813825
# onehotencoder__flat_model_Model A2: 81852.86744183036
# onehotencoder__flat_model_Multi Generation: 76330.21877923148
# onehotencoder__flat_model_New Generation: 21791.189950273023
# onehotencoder__flat_model_Premium Apartment: 22201.794133381627
# onehotencoder__flat_model_Simplified: 27833.072524595256
# onehotencoder__flat_model_Standard: -824.1862608070987
# onehotencoder__flat_model_Terrace: 416161.12039173336
# onehotencoder__flat_model_Type S1: 60165.08007855105
# onehotencoder__flat_model_Type S2: 99717.78058267255
# onehotencoder__storey_category_Low: -117854.49230624974
# onehotencoder__storey_category_Mid-High: -47804.94032598933
# onehotencoder__storey_category_Mid-Low: -42211.44729435293
# onehotencoder__region_OCR: -112411.17553039736
# onehotencoder__region_RCR: 14754.927537792726
# onehotencoder__matched_address_1 BEDOK SOUTH AVENUE 1 SINGAPORE 460001: -34909.02776533577
# onehotencoder__matched_address_1 CHAI CHEE ROAD PING YI GARDENS SINGAPORE 461001: -54173.482036613874
# onehotencoder__matched_address_1 CHANGI VILLAGE ROAD SINGAPORE 500001: 9729.01543558207
# onehotencoder__matched_address_1 DELTA AVENUE SINGAPORE 160001: 8416.46865432911
# onehotencoder__matched_address_1 DOVER ROAD DOVER COMMUNITY CENTRE SINGAPORE 130001: -17564.246959211643
# onehotencoder__matched_address_1 EVERTON PARK EVERTON PARK SINGAPORE 081001: -11062.437753841286
# onehotencoder__matched_address_1 GHIM MOH ROAD GHIM MOH GREEN SINGAPORE 270001: -60575.96463316295
# onehotencoder__matched_address_1 HAIG ROAD HAIG VIEW SINGAPORE 430001: -35091.22990594221
# onehotencoder__matched_address_1 HOUGANG AVENUE 3 SINGAPORE 530001: 28280.730995123653
# onehotencoder__matched_address_1 JALAN BUKIT MERAH BRICKWORKS ESTATE SINGAPORE 150001: -58785.63081655409
# onehotencoder__matched_address_1 KAMPONG KAYU ROAD DI TANJONG RHU SINGAPORE 431001: -46818.82056792743
# onehotencoder__matched_address_1 LORONG 7 TOA PAYOH KIM KEAT COURT SINGAPORE 310001: -19361.78645859938
# onehotencoder__matched_address_1 LORONG LEW LIAN LEW LIAN GARDENS SINGAPORE 531001: -82557.80763300543
# onehotencoder__matched_address_1 MARINE TERRACE MARINE TERRACE WALK SINGAPORE 440001: 85019.66115803899
# onehotencoder__matched_address_1 MARSILING DRIVE MARSILING SPRING SINGAPORE 730001: 124780.59309019847
# onehotencoder__matched_address_1 PINE CLOSE SINGAPORE 390001: 4151.131203989386
# onehotencoder__matched_address_1 QUEEN'S ROAD FARRER GARDENS SINGAPORE 260001: 89969.22156146994
# onehotencoder__matched_address_1 SAINT GEORGE'S ROAD SINGAPORE 320001: -75073.93650401087
# onehotencoder__matched_address_1 TANJONG PAGAR PLAZA MULTI STOREY CAR PARK SINGAPORE 082001: -38105.26693696844
# onehotencoder__matched_address_1 TECK WHYE AVENUE TECK WHYE HEIGHTS I SINGAPORE 680001: 45680.36318900703
# onehotencoder__matched_address_1 TELOK BLANGAH CRESCENT MOUNT FABER GREEN SINGAPORE 090001: -56380.05065486313
# onehotencoder__matched_address_1 TOH YI DRIVE NEIGHBOURHOOD POLICE POST BUKIT TIMAH SINGAPORE 591501: 16771.78646659087
# onehotencoder__matched_address_10 CHAI CHEE ROAD SINGAPORE 467010: 15153.584815001353
# onehotencoder__matched_address_10 EUNOS CRESCENT SINGAPORE 400010: -22010.73958780363
# onehotencoder__matched_address_10 GLOUCESTER ROAD FARRER PARK GARDENS SINGAPORE 210010: 10963.154696865173
# onehotencoder__matched_address_10 HAIG ROAD HAIG VIEW SINGAPORE 430010: -30478.69885527641
# onehotencoder__matched_address_10 HOLLAND AVENUE HOLLAND VISTA SINGAPORE 271010: -41017.44697501464
# onehotencoder__matched_address_10 JALAN BATU DI TANJONG RHU SINGAPORE 431010: 8402.455200977354
# onehotencoder__matched_address_10 JALAN BUKIT HO SWEE BUKIT HO SWEE VIEW SINGAPORE 161010: -59587.39875198279
# onehotencoder__matched_address_10 JALAN KUKOH CHIN SWEE VIEW SINGAPORE 162010: -1928.0758596817982
# onehotencoder__matched_address_10 JALAN RUMAH TINGGI RUMAH TINGGI VIEW SINGAPORE 150010: -37262.60725710053
# onehotencoder__matched_address_10 JOO SENG ROAD SINGAPORE 360010: 2319.3579898409675
# onehotencoder__matched_address_10 LORONG 7 TOA PAYOH TOA PAYOH COURT SINGAPORE 310010: 30376.222314931732
# onehotencoder__matched_address_10 MARSILING DRIVE MARSILING GARDENS SINGAPORE 730010: -11915.294582666107
# onehotencoder__matched_address_10 PINE CLOSE SINGAPORE 391010: -64430.6240979532
# onehotencoder__matched_address_10 SAINT GEORGE'S ROAD SAINT GEORGE'S EAST GARDENS SINGAPORE 320010: -54460.74509174424
# onehotencoder__matched_address_10 SELEGIE ROAD SELEGIE HOUSE SINGAPORE 180010: 11453.177913078394
# onehotencoder__matched_address_10 TECK WHYE AVENUE PCF SPARKLETOTS PRESCHOOL @ CHUA CHU KANG BLK 10 (KN) SINGAPORE 680010: 102494.4583410242
# onehotencoder__matched_address_10 TELOK BLANGAH CRESCENT SINGAPORE 090010: -7732.146442935331
# onehotencoder__matched_address_10 TOH YI DRIVE TOH YI GARDENS SINGAPORE 590010: 34039.40893805633
# onehotencoder__matched_address_100 BEDOK NORTH AVENUE 4 BEDOK POND 1 SINGAPORE 460100: -2803.5425926288376
# onehotencoder__matched_address_100 COMMONWEALTH CRESCENT CRESCENT VIEW SINGAPORE 140100: 6771.50090674981
# onehotencoder__matched_address_100 LORONG 1 TOA PAYOH TOA PAYOH PALM SPRING SINGAPORE 310100: -54037.43365486626
# onehotencoder__matched_address_100 WHAMPOA DRIVE WHAMPOA VIEW SINGAPORE 320100: -19143.213914906686
# onehotencoder__matched_address_101 AH HOOD ROAD AH HOOD GARDENS SINGAPORE 320101: 23066.753415067513
# onehotencoder__matched_address_101 ALJUNIED CRESCENT SINGAPORE 380101: 7865.027676393523
# onehotencoder__matched_address_101 ANG MO KIO AVENUE 3 KEBUN BARU HEIGHTS SINGAPORE 560101: 7736.4724768366395
# onehotencoder__matched_address_101 BEDOK NORTH AVENUE 4 PEARL GARDEN SINGAPORE 460101: 46367.38313054972
# onehotencoder__matched_address_101 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470101: -60177.10555638347
# onehotencoder__matched_address_101 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570101: 39471.31135190002
# onehotencoder__matched_address_101 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650101: -40888.569997483944
# onehotencoder__matched_address_101 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090101: 4424.765261791057
# onehotencoder__matched_address_101 CLEMENTI STREET 14 SUNSET WAY RESIDENCE SINGAPORE 120101: 19217.968175287046
# onehotencoder__matched_address_101 COMMONWEALTH CRESCENT CRESCENT VIEW SINGAPORE 140101: -28985.245147308928
# onehotencoder__matched_address_101 GANGSA ROAD SINGAPORE 670101: -39533.8055429799
# onehotencoder__matched_address_101 HENDERSON CRESCENT SINGAPORE 150101: -2541.0739425183056
# onehotencoder__matched_address_101 HOUGANG AVENUE 1 SINGAPORE 530101: -23138.847130657126
# onehotencoder__matched_address_101 JALAN RAJAH NEIGHBOURHOOD POLICE POST MOULMEIN SINGAPORE 321101: -35336.57681403555
# onehotencoder__matched_address_101 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600101: 9412.517191996969
# onehotencoder__matched_address_101 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410101: -38298.65221440053
# onehotencoder__matched_address_101 PASIR RIS STREET 12 SINGAPORE 510101: -8424.473611669575
# onehotencoder__matched_address_101 POTONG PASIR AVENUE 1 SINGAPORE 350101: -8174.007416465628
# onehotencoder__matched_address_101 RIVERVALE WALK MY FIRST SKOOL SINGAPORE 540101: -68942.1146679174
# onehotencoder__matched_address_101 SERANGOON NORTH AVENUE 1 HWI YOH COURT SINGAPORE 550101: -28026.972114898363
# onehotencoder__matched_address_101 SIMEI STREET 1 SINGAPORE 520101: -13899.43409781964
# onehotencoder__matched_address_101 TAMPINES STREET 11 SAINT LUKE'S ELDERCARE TAMPINES CENTRE SINGAPORE 521101: -2512.8578223752884
# onehotencoder__matched_address_101 TECK WHYE LANE SINGAPORE 680101: -73259.20457218243
# onehotencoder__matched_address_101 TOWNER ROAD SINGAPORE 322101: 22703.91576045865
# onehotencoder__matched_address_101 WHAMPOA DRIVE WHAMPOA VIEW SINGAPORE 323101: -13187.257533941438
# onehotencoder__matched_address_101 WOODLANDS STREET 13 SINGAPORE 730101: 75550.0051309116
# onehotencoder__matched_address_101 YISHUN AVENUE 5 SINGAPORE 760101: 42554.7848311974
# onehotencoder__matched_address_101A BIDADARI PARK DRIVE ALKAFF COURTVIEW SINGAPORE 341101: 33300.37929918793
# onehotencoder__matched_address_101A CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 751101: 15952.292857478145
# onehotencoder__matched_address_101A LORONG 2 TOA PAYOH TOA PAYOH PALM SPRING SINGAPORE 310101: 53218.9795286906
# onehotencoder__matched_address_101A PUNGGOL FIELD SINGAPORE 821101: -5891.788432055445
# onehotencoder__matched_address_101B CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 752101: 2936.8837807675227
# onehotencoder__matched_address_101B LORONG 2 TOA PAYOH TOA PAYOH PALM SPRING SINGAPORE 311101: 59315.59216499515
# onehotencoder__matched_address_101B PUNGGOL FIELD SINGAPORE 822101: -1363.7398367126616
# onehotencoder__matched_address_101C PUNGGOL FIELD SINGAPORE 823101: -19995.90644373578
# onehotencoder__matched_address_101D PUNGGOL FIELD SINGAPORE 824101: 499.97960048504325
# onehotencoder__matched_address_102 ALJUNIED CRESCENT SINGAPORE 380102: 12123.693360276175
# onehotencoder__matched_address_102 ANG MO KIO AVENUE 3 CHILD AT STREET 11 LTD SINGAPORE 560102: -22915.996877953872
# onehotencoder__matched_address_102 BEDOK NORTH AVENUE 4 PEARL GARDEN SINGAPORE 460102: -11033.853084180912
# onehotencoder__matched_address_102 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470102: 41981.53055030136
# onehotencoder__matched_address_102 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570102: 44779.59080974342
# onehotencoder__matched_address_102 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650102: -20783.97973589941
# onehotencoder__matched_address_102 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090102: 26623.417325873463
# onehotencoder__matched_address_102 CLEMENTI STREET 14 SUNSET WAY RESIDENCE SINGAPORE 120102: 25471.810810594656
# onehotencoder__matched_address_102 COMMONWEALTH CRESCENT CRESCENT VIEW SINGAPORE 140102: -960.9857596335629
# onehotencoder__matched_address_102 GANGSA ROAD SINGAPORE 670102: 685.6656076126421
# onehotencoder__matched_address_102 HENDERSON CRESCENT SINGAPORE 150102: -38113.2969838361
# onehotencoder__matched_address_102 HOUGANG AVENUE 1 SINGAPORE 530102: -11976.693094574479
# onehotencoder__matched_address_102 JALAN DUSUN AH HOOD GARDENS SINGAPORE 320102: -31233.339763794145
# onehotencoder__matched_address_102 JALAN RAJAH RAJAH COURT SINGAPORE 321102: -31179.265425017802
# onehotencoder__matched_address_102 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600102: 3823.069958752963
# onehotencoder__matched_address_102 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410102: 16728.639667079973
# onehotencoder__matched_address_102 PASIR RIS STREET 12 SINGAPORE 510102: 10569.292358475283
# onehotencoder__matched_address_102 POTONG PASIR AVENUE 1 SINGAPORE 350102: -70284.1483596707
# onehotencoder__matched_address_102 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540102: -11344.253165289143
# onehotencoder__matched_address_102 SERANGOON NORTH AVENUE 1 HWI YOH COURT SINGAPORE 550102: 9917.822620503839
# onehotencoder__matched_address_102 SIMEI STREET 1 SINGAPORE 520102: -29398.62940150239
# onehotencoder__matched_address_102 TAMPINES STREET 11 SINGAPORE 521102: -674.0789999614879
# onehotencoder__matched_address_102 TECK WHYE LANE SINGAPORE 680102: -34907.80626084894
# onehotencoder__matched_address_102 TOWNER ROAD SINGAPORE 322102: 8097.217488994747
# onehotencoder__matched_address_102 WOODLANDS STREET 13 SINGAPORE 730102: 54420.44875789077
# onehotencoder__matched_address_102A BIDADARI PARK DRIVE ALKAFF COURTVIEW SINGAPORE 341102: 102991.63614649208
# onehotencoder__matched_address_102A CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 751102: 20154.71696368901
# onehotencoder__matched_address_102A PUNGGOL FIELD SINGAPORE 821102: 220.6289171595539
# onehotencoder__matched_address_102B BIDADARI PARK DRIVE ALKAFF COURTVIEW SINGAPORE 342102: -39823.418549155795
# onehotencoder__matched_address_102B CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 752102: -5450.412784020176
# onehotencoder__matched_address_102B PUNGGOL FIELD SINGAPORE 822102: -5240.049523836175
# onehotencoder__matched_address_102C PUNGGOL FIELD SINGAPORE 823102: -10936.38132980738
# onehotencoder__matched_address_102D PUNGGOL FIELD SINGAPORE 824102: 5557.973269737727
# onehotencoder__matched_address_103 AH HOOD ROAD AH HOOD GARDENS SINGAPORE 320103: -15267.210546853501
# onehotencoder__matched_address_103 ANG MO KIO AVENUE 3 KEBUN BARU HEIGHTS SINGAPORE 560103: -23780.20906410168
# onehotencoder__matched_address_103 BEDOK NORTH AVENUE 4 PCF SPARKLETOTS PRESCHOOL @ FENGSHAN BLK 103 (KN) SINGAPORE 460103: -32654.921233618697
# onehotencoder__matched_address_103 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470103: 3125.972255401487
# onehotencoder__matched_address_103 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570103: 59651.04007190184
# onehotencoder__matched_address_103 BUKIT BATOK CENTRAL SINGAPORE 650103: 126.93719970574489
# onehotencoder__matched_address_103 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090103: 538.200354564734
# onehotencoder__matched_address_103 CLEMENTI STREET 14 SUNSET WAY RESIDENCE SINGAPORE 120103: -16522.6206764237
# onehotencoder__matched_address_103 GANGSA ROAD SINGAPORE 670103: 49589.31625877634
# onehotencoder__matched_address_103 HENDERSON CRESCENT SINGAPORE 150103: -19675.764555889626
# onehotencoder__matched_address_103 HOUGANG AVENUE 1 SINGAPORE 530103: -23348.493791194796
# onehotencoder__matched_address_103 JALAN RAJAH SINGAPORE 321103: 24130.74080403959
# onehotencoder__matched_address_103 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600103: 22489.34551074069
# onehotencoder__matched_address_103 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410103: -14842.95414979967
# onehotencoder__matched_address_103 PASIR RIS STREET 12 SINGAPORE 510103: 9059.745990627789
# onehotencoder__matched_address_103 POTONG PASIR AVENUE 1 SINGAPORE 350103: -127307.91067272563
# onehotencoder__matched_address_103 RIVERVALE WALK PCF SPARKLETOTS PRESCHOOL @ PUNGGOL EAST BLK 103 (KN) SINGAPORE 540103: -13636.371962286836
# onehotencoder__matched_address_103 SERANGOON NORTH AVENUE 1 AMAZING STAR MONTESSORI HOUSE (SN) SINGAPORE 550103: -30097.75228351271
# onehotencoder__matched_address_103 SPOTTISWOODE PARK ROAD SPOTTISWOODE PARK ESTATE SINGAPORE 080103: -2398.81320547506
# onehotencoder__matched_address_103 TAMPINES STREET 11 SINGAPORE 520103: -19721.61072264111
# onehotencoder__matched_address_103 TECK WHYE LANE SINGAPORE 680103: -48622.411890053765
# onehotencoder__matched_address_103 TOWNER ROAD SINGAPORE 322103: 17491.862647347003
# onehotencoder__matched_address_103 WOODLANDS STREET 13 SINGAPORE 730103: 89493.99597619918
# onehotencoder__matched_address_103 YISHUN RING ROAD SINGAPORE 760103: 26600.043864162344
# onehotencoder__matched_address_103A BIDADARI PARK DRIVE ALKAFF COURTVIEW SINGAPORE 341103: -1786.2136190496867
# onehotencoder__matched_address_103A CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 751103: 1188.4194481454192
# onehotencoder__matched_address_103A DEPOT ROAD DEPOT HEIGHTS SINGAPORE 101103: -17560.25519632201
# onehotencoder__matched_address_103A EDGEFIELD PLAINS SINGAPORE 821103: -26559.682843585455
# onehotencoder__matched_address_103B CANBERRA STREET EASTCREEK @ CANBERRA SINGAPORE 752103: -4025.73602555379
# onehotencoder__matched_address_103B DEPOT ROAD DEPOT HEIGHTS SINGAPORE 102103: -4453.957921691143
# onehotencoder__matched_address_103B EDGEFIELD PLAINS SINGAPORE 822103: -10069.27376219303
# onehotencoder__matched_address_103C EDGEFIELD PLAINS SINGAPORE 823103: -23225.062816202524
# onehotencoder__matched_address_104 ALJUNIED CRESCENT SINGAPORE 380104: -38706.737361383515
# onehotencoder__matched_address_104 BEDOK NORTH AVENUE 4 PEARL GARDEN SINGAPORE 460104: -15538.346390740428
# onehotencoder__matched_address_104 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470104: -56492.09849038561
# onehotencoder__matched_address_104 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570104: 2279.5677320137497
# onehotencoder__matched_address_104 BUKIT BATOK CENTRAL SINGAPORE 650104: -12692.528180906373
# onehotencoder__matched_address_104 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090104: -10870.12963244688
# onehotencoder__matched_address_104 CLEMENTI STREET 14 SUNSET WAY RESIDENCE SINGAPORE 120104: 58804.295885441585
# onehotencoder__matched_address_104 GANGSA ROAD SINGAPORE 670104: 9684.7951962478
# onehotencoder__matched_address_104 HENDERSON CRESCENT SINGAPORE 150104: -37693.913798154135
# onehotencoder__matched_address_104 HOUGANG AVENUE 1 SINGAPORE 530104: 84371.62734871318
# onehotencoder__matched_address_104 JALAN DUSUN AH HOOD GARDENS SINGAPORE 320104: 11086.460630376872
# onehotencoder__matched_address_104 JALAN RAJAH SINGAPORE 321104: -20248.962254372713
# onehotencoder__matched_address_104 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600104: 56313.72716800476
# onehotencoder__matched_address_104 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410104: -16674.26871296062
# onehotencoder__matched_address_104 PASIR RIS STREET 12 SINGAPORE 510104: 10352.847742415473
# onehotencoder__matched_address_104 POTONG PASIR AVENUE 1 SINGAPORE 350104: -73420.74540624856
# onehotencoder__matched_address_104 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540104: 6275.169816832365
# onehotencoder__matched_address_104 SERANGOON NORTH AVENUE 1 HWI YOH COURT SINGAPORE 550104: 17877.180314488454
# onehotencoder__matched_address_104 SPOTTISWOODE PARK ROAD SPOTTISWOODE PARK ESTATE SINGAPORE 080104: -6203.1112765034195
# onehotencoder__matched_address_104 TAMPINES STREET 11 SINGAPORE 520104: 24854.06338040743
# onehotencoder__matched_address_104 TECK WHYE LANE SINGAPORE 680104: -37097.03222797628
# onehotencoder__matched_address_104 TOWNER ROAD SINGAPORE 322104: 53175.49654329562
# onehotencoder__matched_address_104 WHAMPOA DRIVE WHAMPOA VIEW SINGAPORE 323104: 23409.940061242847
# onehotencoder__matched_address_104 WOODLANDS STREET 13 SINGAPORE 730104: 11640.072585237638
# onehotencoder__matched_address_104A ANG MO KIO STREET 11 KEBUN BARU HEIGHTS SINGAPORE 560104: 83708.56149811517
# onehotencoder__matched_address_104A CANBERRA STREET EASTBROOK @ CANBERRA SINGAPORE 751104: 1112.9291868267073
# onehotencoder__matched_address_104A DEPOT ROAD DEPOT HEIGHTS SINGAPORE 101104: -7596.451120747954
# onehotencoder__matched_address_104A EDGEFIELD PLAINS SINGAPORE 821104: -18859.0905287378
# onehotencoder__matched_address_104B ANG MO KIO STREET 11 KEBUN BARU HEIGHTS SINGAPORE 561104: 11638.040835291355
# onehotencoder__matched_address_104B CANBERRA STREET EASTBROOK @ CANBERRA SINGAPORE 752104: -3828.025863199711
# onehotencoder__matched_address_104B DEPOT ROAD DEPOT HEIGHTS SINGAPORE 102104: -15140.822642847737
# onehotencoder__matched_address_104B EDGEFIELD PLAINS SINGAPORE 822104: -10098.284140534164
# onehotencoder__matched_address_104C CANBERRA STREET EASTBROOK @ CANBERRA SINGAPORE 753104: -3003.157726820446
# onehotencoder__matched_address_104D CANBERRA STREET EASTBROOK @ CANBERRA SINGAPORE 754104: -10626.48968301576
# onehotencoder__matched_address_105 ALJUNIED CRESCENT SINGAPORE 380105: 24946.244772276874
# onehotencoder__matched_address_105 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560105: -6544.234515848904
# onehotencoder__matched_address_105 BEDOK NORTH AVENUE 4 NKF DIALYSIS CENTRE SINGAPORE 460105: -19060.074060443276
# onehotencoder__matched_address_105 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470105: -912.7881802833034
# onehotencoder__matched_address_105 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570105: 15045.805032806586
# onehotencoder__matched_address_105 BUKIT BATOK CENTRAL SINGAPORE 650105: -19800.8286190792
# onehotencoder__matched_address_105 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090105: 25820.54099862682
# onehotencoder__matched_address_105 CLEMENTI STREET 12 MOUNT PLEASANT ANIMAL MEDICAL CENTRE SINGAPORE 120105: -85794.46132801699
# onehotencoder__matched_address_105 GANGSA ROAD SINGAPORE 670105: 9923.867791023029
# onehotencoder__matched_address_105 HENDERSON CRESCENT HENDERSONVILLE SINGAPORE 150105: -87366.58701553503
# onehotencoder__matched_address_105 JALAN RAJAH PCF SPARKLETOTS PRESCHOOL @ WHAMPOA 105 (CC) SINGAPORE 320105: 17179.22506484129
# onehotencoder__matched_address_105 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600105: -17732.93116667378
# onehotencoder__matched_address_105 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410105: -58834.643413299294
# onehotencoder__matched_address_105 PASIR RIS STREET 12 SINGAPORE 510105: -5181.611882383796
# onehotencoder__matched_address_105 POTONG PASIR AVENUE 1 SINGAPORE 350105: -63133.54896543139
# onehotencoder__matched_address_105 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540105: 8749.740345547872
# onehotencoder__matched_address_105 SERANGOON NORTH AVENUE 1 HWI YOH COURT SINGAPORE 550105: 15698.90488712097
# onehotencoder__matched_address_105 SIMEI STREET 1 SINGAPORE 520105: -7533.46444342316
# onehotencoder__matched_address_105 TAMPINES STREET 11 SINGAPORE 521105: 946.7755836395357
# onehotencoder__matched_address_105 TECK WHYE LANE SINGAPORE 680105: 46478.82205856783
# onehotencoder__matched_address_105 TOWNER ROAD SINGAPORE 321105: 15240.171807707718
# onehotencoder__matched_address_105 WOODLANDS STREET 13 SINGAPORE 730105: 8232.247065328156
# onehotencoder__matched_address_105A BIDADARI PARK DRIVE ALKAFF VISTA SINGAPORE 341105: 186024.35028760316
# onehotencoder__matched_address_105A DEPOT ROAD DEPOT HEIGHTS SINGAPORE 101105: 31594.446630170987
# onehotencoder__matched_address_105A EDGEFIELD PLAINS SINGAPORE 821105: -25317.2416550757
# onehotencoder__matched_address_105B BIDADARI PARK DRIVE ALKAFF VISTA SINGAPORE 342105: 194072.20751223367
# onehotencoder__matched_address_105B EDGEFIELD PLAINS SINGAPORE 822105: 23081.716053616357
# onehotencoder__matched_address_105C EDGEFIELD PLAINS SINGAPORE 823105: 956.4019974978117
# onehotencoder__matched_address_105D EDGEFIELD PLAINS SINGAPORE 824105: 3374.416595017926
# onehotencoder__matched_address_106 ALJUNIED CRESCENT SINGAPORE 380106: -4741.902654605303
# onehotencoder__matched_address_106 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560106: -25363.733768703627
# onehotencoder__matched_address_106 BEDOK NORTH AVENUE 4 PEARL GARDEN SINGAPORE 460106: 34993.25564618242
# onehotencoder__matched_address_106 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470106: -12154.53509399159
# onehotencoder__matched_address_106 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570106: -26771.335283679033
# onehotencoder__matched_address_106 BUKIT BATOK CENTRAL SINGAPORE 650106: -5577.212356355829
# onehotencoder__matched_address_106 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090106: -711.1188619472064
# onehotencoder__matched_address_106 GANGSA ROAD SINGAPORE 670106: 6931.479303636277
# onehotencoder__matched_address_106 HENDERSON CRESCENT SINGAPORE 150106: -63454.49649518384
# onehotencoder__matched_address_106 HOUGANG AVENUE 1 SINGAPORE 530106: 25190.07841579583
# onehotencoder__matched_address_106 JALAN DUSUN AH HOOD GARDENS SINGAPORE 320106: -40382.73831560529
# onehotencoder__matched_address_106 JALAN RAJAH RAJAH COURT SINGAPORE 321106: -56571.51921927358
# onehotencoder__matched_address_106 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600106: -27977.105370281064
# onehotencoder__matched_address_106 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410106: 47900.771483723154
# onehotencoder__matched_address_106 PASIR RIS STREET 12 SINGAPORE 510106: -7621.546934870548
# onehotencoder__matched_address_106 POTONG PASIR AVENUE 1 SINGAPORE 350106: -4614.843582583051
# onehotencoder__matched_address_106 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540106: -207.1425052322616
# onehotencoder__matched_address_106 SERANGOON NORTH AVENUE 1 HWI YOH COURT SINGAPORE 550106: 17671.25055420639
# onehotencoder__matched_address_106 SIMEI STREET 1 SINGAPORE 520106: 9589.293060947273
# onehotencoder__matched_address_106 SPOTTISWOODE PARK ROAD SPOTTISWOODE PARK ESTATE SINGAPORE 080106: 11858.668158811799
# onehotencoder__matched_address_106 TAMPINES STREET 11 SINGAPORE 521106: -30731.152750383913
# onehotencoder__matched_address_106 TECK WHYE LANE SINGAPORE 680106: 46298.25747727316
# onehotencoder__matched_address_106 TOWNER ROAD SINGAPORE 322106: 36476.29818317609
# onehotencoder__matched_address_106 WOODLANDS STREET 13 SINGAPORE 730106: 97858.82029766466
# onehotencoder__matched_address_106 YISHUN RING ROAD CHONG PANG GARDEN SINGAPORE 760106: 25927.603845564176
# onehotencoder__matched_address_106A BIDADARI PARK DRIVE ALKAFF VISTA SINGAPORE 341106: 36169.84974936049
# onehotencoder__matched_address_106A DEPOT ROAD DEPOT HEIGHTS SINGAPORE 101106: 27593.47039547467
# onehotencoder__matched_address_106A PUNGGOL FIELD SINGAPORE 821106: 14304.751960959766
# onehotencoder__matched_address_106B BIDADARI PARK DRIVE ALKAFF VISTA SINGAPORE 342106: 61224.47266404841
# onehotencoder__matched_address_106B DEPOT ROAD DEPOT HEIGHTS SINGAPORE 102106: 378.0146388745351
# onehotencoder__matched_address_106B PUNGGOL FIELD SINGAPORE 822106: 14649.789614541649
# onehotencoder__matched_address_106C PUNGGOL FIELD SINGAPORE 823106: -6197.496560398835
# onehotencoder__matched_address_106D PUNGGOL FIELD SINGAPORE 824106: -1564.4691776472027
# onehotencoder__matched_address_107 ALJUNIED CRESCENT SINGAPORE 380107: 12541.524764790642
# onehotencoder__matched_address_107 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560107: -18034.62563687438
# onehotencoder__matched_address_107 BEDOK NORTH ROAD FENGSHAN ESTATE SINGAPORE 460107: 9876.098741815831
# onehotencoder__matched_address_107 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470107: 4544.075704821065
# onehotencoder__matched_address_107 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570107: -33880.470540615635
# onehotencoder__matched_address_107 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650107: 16859.15237585714
# onehotencoder__matched_address_107 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090107: -15401.701093957607
# onehotencoder__matched_address_107 GANGSA ROAD SINGAPORE 670107: 1460.010528679884
# onehotencoder__matched_address_107 JALAN BUKIT MERAH TIONG BAHRU ORCHID SINGAPORE 160107: -5076.632047067379
# onehotencoder__matched_address_107 JALAN RAJAH RAJAH COURT SINGAPORE 320107: -31368.718305801292
# onehotencoder__matched_address_107 JURONG EAST STREET 13 CHAMPIONS LEARNING COVE SINGAPORE 600107: -48879.50090682246
# onehotencoder__matched_address_107 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410107: -23995.419637277548
# onehotencoder__matched_address_107 LORONG 1 TOA PAYOH TOA PAYOH NORTH SINGAPORE 310107: -5015.178764149902
# onehotencoder__matched_address_107 PASIR RIS STREET 12 SINGAPORE 510107: -18104.496370908866
# onehotencoder__matched_address_107 POTONG PASIR AVENUE 1 SINGAPORE 350107: -62587.96466397807
# onehotencoder__matched_address_107 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540107: -903.7351704478644
# onehotencoder__matched_address_107 SERANGOON NORTH AVENUE 1 DISTINCT STUDENT CARE AND ENRICHMENT CENTRE SINGAPORE 550107: 10381.286243476949
# onehotencoder__matched_address_107 SIMEI STREET 1 SINGAPORE 520107: 19719.829297725093
# onehotencoder__matched_address_107 TAMPINES STREET 11 SINGAPORE 521107: 18524.93827697371
# onehotencoder__matched_address_107 TECK WHYE LANE SINGAPORE 680107: -72331.7671537568
# onehotencoder__matched_address_107 TOWNER ROAD SINGAPORE 321107: 960.884393107172
# onehotencoder__matched_address_107 WOODLANDS STREET 13 SINGAPORE 730107: -84962.05315623185
# onehotencoder__matched_address_107 YISHUN RING ROAD CHONG PANG GARDEN SINGAPORE 760107: 15095.020780360415
# onehotencoder__matched_address_107A CANBERRA STREET EASTBROOK @ CANBERRA SINGAPORE 751107: 1855.8672898255197
# onehotencoder__matched_address_107A EDGEFIELD PLAINS SINGAPORE 821107: -9150.701562152222
# onehotencoder__matched_address_107B CANBERRA STREET EASTBROOK @ CANBERRA SINGAPORE 752107: 1053.924412625279
# onehotencoder__matched_address_107B EDGEFIELD PLAINS SINGAPORE 822107: -1755.0646409631167
# onehotencoder__matched_address_107C CANBERRA STREET EASTBROOK @ CANBERRA SINGAPORE 753107: -21297.344347384304
# onehotencoder__matched_address_107C EDGEFIELD PLAINS SINGAPORE 823107: -4484.188416578654
# onehotencoder__matched_address_107D EDGEFIELD PLAINS SINGAPORE 824107: -21797.077582298552
# onehotencoder__matched_address_108 ALJUNIED CRESCENT SINGAPORE 380108: -10402.261246769873
# onehotencoder__matched_address_108 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560108: -20007.148600012155
# onehotencoder__matched_address_108 BEDOK NORTH ROAD FENGSHAN ESTATE SINGAPORE 460108: -5981.367960929785
# onehotencoder__matched_address_108 BEDOK RESERVOIR ROAD CARPE DIEM KINDERCARE PTE. LTD. SINGAPORE 470108: 11574.353838514553
# onehotencoder__matched_address_108 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570108: -67424.27565771628
# onehotencoder__matched_address_108 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650108: 31434.355656344036
# onehotencoder__matched_address_108 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090108: -4346.32475404325
# onehotencoder__matched_address_108 COMMONWEALTH CRESCENT SINGAPORE 140108: -20210.736652943273
# onehotencoder__matched_address_108 GANGSA ROAD SINGAPORE 670108: 7503.561421846185
# onehotencoder__matched_address_108 HOUGANG AVENUE 1 SINGAPORE 530108: 50686.67635608462
# onehotencoder__matched_address_108 JALAN BUKIT MERAH SINGAPORE 160108: -6147.99853151895
# onehotencoder__matched_address_108 JALAN RAJAH RAJAH COURT SINGAPORE 320108: -20849.820158819726
# onehotencoder__matched_address_108 JURONG EAST STREET 13 DOVER CLEMENTI SPORTS CLUB SINGAPORE 600108: 742.7043365737709
# onehotencoder__matched_address_108 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410108: 39685.13018452681
# onehotencoder__matched_address_108 LORONG 1 TOA PAYOH TOA PAYOH NORTH SINGAPORE 310108: 23313.17222637009
# onehotencoder__matched_address_108 MCNAIR ROAD MCNAIR SPRING SINGAPORE 321108: 26964.898830277474
# onehotencoder__matched_address_108 PASIR RIS STREET 12 SINGAPORE 510108: -9836.121102090032
# onehotencoder__matched_address_108 POTONG PASIR AVENUE 1 SINGAPORE 350108: -19288.62805823269
# onehotencoder__matched_address_108 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540108: -7817.150693941768
# onehotencoder__matched_address_108 SERANGOON NORTH AVENUE 1 HWI YOH COURT SINGAPORE 550108: 21641.63927582133
# onehotencoder__matched_address_108 SIMEI STREET 1 SINGAPORE 520108: 3691.1602584758234
# onehotencoder__matched_address_108 TAMPINES STREET 11 SINGAPORE 521108: 12798.885080285845
# onehotencoder__matched_address_108 TECK WHYE LANE SINGAPORE 680108: -53637.9898586725
# onehotencoder__matched_address_108 WOODLANDS STREET 13 SINGAPORE 730108: -10910.334948331576
# onehotencoder__matched_address_108 YISHUN RING ROAD SINGAPORE 760108: 1128.1261521981733
# onehotencoder__matched_address_108A CANBERRA WALK EASTLAWN @ CANBERRA SINGAPORE 751108: 15438.800529135773
# onehotencoder__matched_address_108B CANBERRA WALK EASTLAWN @ CANBERRA SINGAPORE 752108: 3955.73401114299
# onehotencoder__matched_address_108B MCNAIR ROAD TOWNER HEIGHTS SINGAPORE 323108: 19142.571405762672
# onehotencoder__matched_address_108C CANBERRA WALK EASTLAWN @ CANBERRA SINGAPORE 753108: 6796.952160952092
# onehotencoder__matched_address_108C MCNAIR ROAD TOWNER HEIGHTS SINGAPORE 324108: 29332.515028908827
# onehotencoder__matched_address_109 ALJUNIED CRESCENT SINGAPORE 380109: -34151.18205494595
# onehotencoder__matched_address_109 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560109: 22111.26864028784
# onehotencoder__matched_address_109 BEDOK NORTH ROAD FENGSHAN ESTATE SINGAPORE 460109: 2095.848178186435
# onehotencoder__matched_address_109 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470109: 59285.51796975625
# onehotencoder__matched_address_109 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570109: -23418.72545919511
# onehotencoder__matched_address_109 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650109: 43272.00730454654
# onehotencoder__matched_address_109 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090109: 7389.8123937742985
# onehotencoder__matched_address_109 CLEMENTI STREET 11 SUNSET WAY RESIDENCE SINGAPORE 120109: -85748.99039784892
# onehotencoder__matched_address_109 COMMONWEALTH CRESCENT SINGAPORE 140109: -13979.410716038226
# onehotencoder__matched_address_109 GANGSA ROAD SINGAPORE 670109: 43586.80690006306
# onehotencoder__matched_address_109 HOUGANG AVENUE 1 SINGAPORE 530109: 10518.442492820577
# onehotencoder__matched_address_109 JALAN BUKIT MERAH SINGAPORE 160109: 1495.966563748569
# onehotencoder__matched_address_109 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600109: -8029.323523327035
# onehotencoder__matched_address_109 LENGKONG TIGA KEMBANGAN GARDENS SINGAPORE 410109: 32242.007946209764
# onehotencoder__matched_address_109 LORONG 1 TOA PAYOH TOA PAYOH NORTH SINGAPORE 310109: 20128.53344486571
# onehotencoder__matched_address_109 MCNAIR ROAD MCNAIR SPRING SINGAPORE 320109: 29453.200440703695
# onehotencoder__matched_address_109 PASIR RIS STREET 11 SINGAPORE 510109: -16112.133478913995
# onehotencoder__matched_address_109 POTONG PASIR AVENUE 1 SINGAPORE 350109: -13977.163649537413
# onehotencoder__matched_address_109 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540109: -77055.8093077207
# onehotencoder__matched_address_109 SERANGOON NORTH AVENUE 1 HWI YOH VILLE SINGAPORE 550109: 4303.703240099419
# onehotencoder__matched_address_109 SIMEI STREET 1 SINGAPORE 520109: 15157.650316212703
# onehotencoder__matched_address_109 SPOTTISWOODE PARK ROAD SPOTTISWOODE PARK ESTATE SINGAPORE 080109: 23570.50896704689
# onehotencoder__matched_address_109 TAMPINES STREET 11 SINGAPORE 521109: 10020.799551576813
# onehotencoder__matched_address_109 TECK WHYE LANE SINGAPORE 680109: -65840.30929832502
# onehotencoder__matched_address_109 WHAMPOA ROAD WHAMPOA GARDENS SINGAPORE 321109: -6927.889505090082
# onehotencoder__matched_address_109 WOODLANDS STREET 13 SINGAPORE 730109: -20585.859758211907
# onehotencoder__matched_address_109 YISHUN RING ROAD CHONG PANG GARDEN SINGAPORE 760109: -9566.939248073451
# onehotencoder__matched_address_109A DEPOT ROAD DEPOT HEIGHTS SINGAPORE 101109: -15575.242164525816
# onehotencoder__matched_address_109A EDGEDALE PLAINS SINGAPORE 821109: -23549.432433640908
# onehotencoder__matched_address_109B DEPOT ROAD DEPOT HEIGHTS SINGAPORE 102109: -15581.991628302912
# onehotencoder__matched_address_109B EDGEDALE PLAINS SINGAPORE 822109: 9521.217816011656
# onehotencoder__matched_address_109C EDGEDALE PLAINS SINGAPORE 823109: 7579.16136705322
# onehotencoder__matched_address_109D EDGEDALE PLAINS SINGAPORE 824109: -24181.31098850983
# onehotencoder__matched_address_10A BENDEMEER ROAD BENDEMEER LIGHT SINGAPORE 331010: -21018.479976278835
# onehotencoder__matched_address_10A BOON TIONG ROAD TIONG BAHRU VIEW SINGAPORE 160010: -24723.057412571587
# onehotencoder__matched_address_10B BEDOK SOUTH AVENUE 2 SINGAPORE 461010: -3926.2446994621487
# onehotencoder__matched_address_10B BENDEMEER ROAD BENDEMEER LIGHT SINGAPORE 332010: 21569.343406038042
# onehotencoder__matched_address_10B BOON TIONG ROAD TIONG BAHRU VIEW SINGAPORE 164010: 8235.592603503084
# onehotencoder__matched_address_10B LORONG 7 TOA PAYOH TOA PAYOH COURT SINGAPORE 312010: 4021.0741185905445
# onehotencoder__matched_address_10C BENDEMEER ROAD BENDEMEER LIGHT SINGAPORE 333010: 5765.027795673839
# onehotencoder__matched_address_10D BEDOK SOUTH AVENUE 2 SINGAPORE 463010: 16242.587505021133
# onehotencoder__matched_address_10E BEDOK SOUTH AVENUE 2 SINGAPORE 464010: -19714.461878401424
# onehotencoder__matched_address_10F BEDOK SOUTH AVENUE 2 SINGAPORE 465010: -3508.874164636124
# onehotencoder__matched_address_11 CANTONMENT CLOSE CANTONMENT TOWERS SINGAPORE 080011: 15439.568902526677
# onehotencoder__matched_address_11 CHAI CHEE ROAD SINGAPORE 460011: 1285.2471443694512
# onehotencoder__matched_address_11 EUNOS CRESCENT SINGAPORE 400011: -44351.14758938622
# onehotencoder__matched_address_11 FARRER PARK ROAD FARRER PARK VIEW SINGAPORE 210011: 337.8881792890231
# onehotencoder__matched_address_11 HAIG ROAD HAIG VIEW SINGAPORE 430011: 13694.943186716922
# onehotencoder__matched_address_11 HOLLAND GROVE DRIVE SINGAPORE 278859: -7630.621292825128
# onehotencoder__matched_address_11 JALAN BATU DI TANJONG RHU SINGAPORE 431011: 39029.68177545625
# onehotencoder__matched_address_11 JALAN BUKIT MERAH SINGAPORE 150011: -71212.55238516179
# onehotencoder__matched_address_11 JOO SENG ROAD SINGAPORE 360011: 9728.223032840202
# onehotencoder__matched_address_11 LORONG 8 TOA PAYOH TOA PAYOH COURT SINGAPORE 310011: 4339.62659393791
# onehotencoder__matched_address_11 MARSILING DRIVE MARSILING GARDENS SINGAPORE 730011: -51972.43911855612
# onehotencoder__matched_address_11 PINE CLOSE SINGAPORE 391011: 2986.2142926066763
# onehotencoder__matched_address_11 SAINT GEORGE'S ROAD SAINT GEORGE'S EAST GARDENS SINGAPORE 320011: -60327.15618501501
# onehotencoder__matched_address_11 TECK WHYE LANE TECK WHYE HEIGHTS II SINGAPORE 680011: 6250.8485231916275
# onehotencoder__matched_address_11 TOH YI DRIVE TOH YI GARDENS SINGAPORE 590011: -21292.342027974468
# onehotencoder__matched_address_11 UPPER BOON KENG ROAD BOON KENG VILLE SINGAPORE 380011: -54794.800529317334
# onehotencoder__matched_address_110 ALJUNIED CRESCENT SINGAPORE 380110: 53900.436376934806
# onehotencoder__matched_address_110 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560110: 12779.003148739765
# onehotencoder__matched_address_110 BEDOK NORTH ROAD FENGSHAN ESTATE SINGAPORE 460110: 10496.461868554043
# onehotencoder__matched_address_110 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470110: -10214.840305253034
# onehotencoder__matched_address_110 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570110: -6672.862141349599
# onehotencoder__matched_address_110 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650110: 13145.845089161883
# onehotencoder__matched_address_110 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090110: -20194.219441341367
# onehotencoder__matched_address_110 CLEMENTI STREET 13 SUNSET WAY RESIDENCE SINGAPORE 120110: 46158.45996712318
# onehotencoder__matched_address_110 COMMONWEALTH CRESCENT SINGAPORE 140110: -9068.238651861913
# onehotencoder__matched_address_110 GANGSA ROAD SINGAPORE 670110: -25066.115264130585
# onehotencoder__matched_address_110 HOUGANG AVENUE 1 SINGAPORE 530110: 5471.253175609808
# onehotencoder__matched_address_110 JURONG EAST STREET 13 HAPPY TALENT CHILDCARE CENTRE PTE. LTD. SINGAPORE 600110: 14044.779440087766
# onehotencoder__matched_address_110 LENGKONG TIGA SINGAPORE 410110: -11895.426646394759
# onehotencoder__matched_address_110 LORONG 1 TOA PAYOH TOA PAYOH NORTH SINGAPORE 310110: 19355.247283295696
# onehotencoder__matched_address_110 MCNAIR ROAD MCNAIR SPRING SINGAPORE 320110: 52340.4802223737
# onehotencoder__matched_address_110 PASIR RIS STREET 11 SINGAPORE 510110: -1384.2979505017452
# onehotencoder__matched_address_110 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540110: -35799.16459300602
# onehotencoder__matched_address_110 SERANGOON NORTH AVENUE 1 HWI YOH VILLE SINGAPORE 550110: 40922.201473310364
# onehotencoder__matched_address_110 SIMEI STREET 1 SINGAPORE 520110: 23200.60086288149
# onehotencoder__matched_address_110 SPOTTISWOODE PARK ROAD SPOTTISWOODE PARK ESTATE SINGAPORE 081110: 22809.353978588162
# onehotencoder__matched_address_110 TAMPINES STREET 11 SINGAPORE 521110: -10547.032772326782
# onehotencoder__matched_address_110 TECK WHYE LANE SINGAPORE 680110: 24369.986954504202
# onehotencoder__matched_address_110 WHAMPOA ROAD WHAMPOA GARDENS SINGAPORE 321110: -31445.206367154213
# onehotencoder__matched_address_110 WOODLANDS STREET 13 SINGAPORE 730110: 5670.95470501978
# onehotencoder__matched_address_110 YISHUN RING ROAD CHONG PANG GARDEN SINGAPORE 760110: 7371.920719202358
# onehotencoder__matched_address_110A DEPOT ROAD DEPOT HEIGHTS SINGAPORE 101110: 19407.244214314494
# onehotencoder__matched_address_110A PUNGGOL FIELD SINGAPORE 821110: -7951.219971975135
# onehotencoder__matched_address_110B PUNGGOL FIELD SINGAPORE 822110: 12267.378018130108
# onehotencoder__matched_address_110C PUNGGOL FIELD SINGAPORE 823110: -1540.0558823000597
# onehotencoder__matched_address_110D PUNGGOL FIELD SINGAPORE 824110: 12698.448732038352
# onehotencoder__matched_address_111 ALJUNIED CRESCENT SINGAPORE 380111: -11851.486154560545
# onehotencoder__matched_address_111 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560111: 1275.0813765377825
# onehotencoder__matched_address_111 BEDOK NORTH ROAD SINGAPORE 460111: -32341.327807134097
# onehotencoder__matched_address_111 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470111: -8072.554252442204
# onehotencoder__matched_address_111 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570111: -749.0439245457778
# onehotencoder__matched_address_111 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650111: -6196.197451478754
# onehotencoder__matched_address_111 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090111: 8434.96928742472
# onehotencoder__matched_address_111 CLEMENTI STREET 13 SUNSET WAY RESIDENCE SINGAPORE 120111: -22398.14506173515
# onehotencoder__matched_address_111 COMMONWEALTH CRESCENT SINGAPORE 140111: -31868.887616946067
# onehotencoder__matched_address_111 EDGEFIELD PLAINS SINGAPORE 820111: -4323.343659221209
# onehotencoder__matched_address_111 GANGSA ROAD SINGAPORE 670111: -49282.60736973525
# onehotencoder__matched_address_111 HO CHING ROAD SINGAPORE 610111: 132901.54010331462
# onehotencoder__matched_address_111 HOUGANG AVENUE 1 SINGAPORE 530111: 39713.00628111026
# onehotencoder__matched_address_111 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600111: 4923.599184017814
# onehotencoder__matched_address_111 LENGKONG TIGA SINGAPORE 410111: 17671.940931206696
# onehotencoder__matched_address_111 LORONG 1 TOA PAYOH TOA PAYOH NORTH SINGAPORE 310111: -24576.82935672215
# onehotencoder__matched_address_111 LORONG 3 GEYLANG SINGAPORE 381111: -18448.148351719203
# onehotencoder__matched_address_111 MCNAIR ROAD MCNAIR SPRING SINGAPORE 320111: 26150.80096196459
# onehotencoder__matched_address_111 PASIR RIS STREET 11 SINGAPORE 510111: 17261.71966966841
# onehotencoder__matched_address_111 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540111: -10695.441226202973
# onehotencoder__matched_address_111 SERANGOON NORTH AVENUE 1 HWI YOH VILLE SINGAPORE 550111: -33168.57023017123
# onehotencoder__matched_address_111 SIMEI STREET 1 SINGAPORE 520111: 18017.194715752772
# onehotencoder__matched_address_111 TAMPINES STREET 11 SINGAPORE 521111: -170.86528144335
# onehotencoder__matched_address_111 TECK WHYE LANE SINGAPORE 680111: 37028.24602370371
# onehotencoder__matched_address_111 WHAMPOA ROAD WHAMPOA GARDENS SINGAPORE 321111: -25710.699098347402
# onehotencoder__matched_address_111 WOODLANDS STREET 13 SINGAPORE 730111: -20478.457180135978
# onehotencoder__matched_address_111 YISHUN RING ROAD CHONG PANG GARDEN SINGAPORE 760111: 50422.34137046195
# onehotencoder__matched_address_111A DEPOT ROAD DEPOT HEIGHTS SINGAPORE 101111: -1577.0116818601307
# onehotencoder__matched_address_111B DEPOT ROAD DEPOT HEIGHTS SINGAPORE 102111: 10597.294672313548
# onehotencoder__matched_address_112 ALJUNIED CRESCENT SINGAPORE 380112: -5867.511774227802
# onehotencoder__matched_address_112 ANG MO KIO AVENUE 4 KEBUN BARU HEIGHTS SINGAPORE 560112: -6348.583292681433
# onehotencoder__matched_address_112 BEDOK NORTH ROAD SINGAPORE 460112: -22801.33596892691
# onehotencoder__matched_address_112 BEDOK RESERVOIR ROAD EUNOS VISTA SINGAPORE 470112: -49310.148477360955
# onehotencoder__matched_address_112 BISHAN STREET 12 BISHAN VIEW SINGAPORE 570112: -11260.548777440186
# onehotencoder__matched_address_112 BUKIT BATOK WEST AVENUE 6 SINGAPORE 650112: -13996.389751857152
# onehotencoder__matched_address_112 BUKIT PURMEI ROAD BUKIT PURMEI VILLE SINGAPORE 090112: -10645.454427143663
# onehotencoder__matched_address_112 CLEMENTI STREET 13 SUNSET WAY RESIDENCE SINGAPORE 120112: 98853.34165853489
# onehotencoder__matched_address_112 COMMONWEALTH CRESCENT SINGAPORE 140112: -34954.685437049695
# onehotencoder__matched_address_112 EDGEFIELD PLAINS SINGAPORE 820112: -16809.341567550407
# onehotencoder__matched_address_112 HO CHING ROAD SINGAPORE 610112: 100505.71566181809
# onehotencoder__matched_address_112 HOUGANG AVENUE 1 SINGAPORE 530112: 13618.873585331277
# onehotencoder__matched_address_112 JURONG EAST STREET 13 JURONG EAST VILLE SINGAPORE 600112: -13553.18154585403
# onehotencoder__matched_address_112 LENGKONG TIGA SINGAPORE 410112: 27768.02875452941
# onehotencoder__matched_address_112 LORONG 1 TOA PAYOH TOA PAYOH NORTH SINGAPORE 310112: 26699.783656473377
# onehotencoder__matched_address_112 LORONG 3 GEYLANG SINGAPORE 381112: -9674.723474205275
# onehotencoder__matched_address_112 MCNAIR ROAD MCNAIR SPRING SINGAPORE 320112: -46740.359544595136
# onehotencoder__matched_address_112 PASIR RIS STREET 11 SINGAPORE 510112: -1727.4769108026453
# onehotencoder__matched_address_112 PENDING ROAD SINGAPORE 670112: 5306.305741028825
# onehotencoder__matched_address_112 RIVERVALE WALK RIVERVALE COURT SINGAPORE 540112: -8890.639634842677
# onehotencoder__matched_address_112 SERANGOON NORTH AVENUE 1 HWI YOH VILLE SINGAPORE 550112: 44528.8827488308
# onehotencoder__matched_address_112 SIMEI STREET 1 SINGAPORE 520112: -2100.9997300886007
# onehotencoder__matched_address_112 TAMPINES STREET 11 SINGAPORE 521112: 3759.7821006270788
# onehotencoder__matched_address_112 TECK WHYE LANE SINGAPORE 680112: -37221.35110034628
# onehotencoder__matched_address_112 WHAMPOA ROAD PCF SPARKLETOTS PRESCHOOL @ WHAMPOA BLK 112 (KN) SINGAPORE 321112: 3982.7763151004265
# onehotencoder__matched_address_112 WOODLANDS STREET 13 SINGAPORE 730112: 30145.90454135924
# onehotencoder__matched_address_112 YISHUN RING ROAD CHONG PANG VALE SINGAPORE 760112: 7541.654015791874
# ...
# onehotencoder__nearest_park_name_MERA TERRACE PG: -19979.245324125553
# onehotencoder__nearest_park_name_MERAGI RD PG: -3081.350706443425
# onehotencoder__nearest_park_name_MOUNT EMILY PK: -5153.928317488241
# onehotencoder__nearest_park_name_MOUNT FABER PARK: -12265.092374184624
# onehotencoder__nearest_park_name_MT BATTEN RD/OLD AIRPORT RD OS: 15281.604902495294
# onehotencoder__nearest_park_name_MUGLISTON PK PG: -39430.05883170552
# onehotencoder__nearest_park_name_NIM MEADOW PARK: -15803.512078379137
# onehotencoder__nearest_park_name_NORTH BRIDGE GARDEN: 19913.130655187415
# onehotencoder__nearest_park_name_NOVENA RISE PK: -8166.586348722062
# onehotencoder__nearest_park_name_OASIS@MULBERRY PK: 13389.063335867559
# onehotencoder__nearest_park_name_ONE-NORTH PARK: -21058.672068481264
# onehotencoder__nearest_park_name_PANDAN RESERVOIR FITNESS CORNER: 35593.80576268125
# onehotencoder__nearest_park_name_PARK AT SEMBAWANG ALLEY: -24747.16888555871
# onehotencoder__nearest_park_name_PARRY RD PG: -33201.351513329995
# onehotencoder__nearest_park_name_PASIR RIS PK: 1702.3761058934372
# onehotencoder__nearest_park_name_PASIR RIS TOWN PK: 2657.537452858112
# onehotencoder__nearest_park_name_PAVILION PARK PLAYGROUND: 1637.4062895450286
# onehotencoder__nearest_park_name_PAYA LEBAR CRESCENT OS: 15985.94602632646
# onehotencoder__nearest_park_name_PAYA LEBAR ROAD PARK: 4983.8720857500775
# onehotencoder__nearest_park_name_PEARL'S HILL CITY PK: -28747.455744425944
# onehotencoder__nearest_park_name_PEBBLE GARDEN: -1897.1614777683294
# onehotencoder__nearest_park_name_PEK KIO PARK: -16607.826227728794
# onehotencoder__nearest_park_name_PEMIMPIN PLACE PG: 26434.170335258957
# onehotencoder__nearest_park_name_PHOENIX PARK: 5704.176805974564
# onehotencoder__nearest_park_name_PK VILLAS TERRACE PG: -28833.54523742761
# onehotencoder__nearest_park_name_PLATINA RD PG: 17484.017531419304
# onehotencoder__nearest_park_name_POH HUAT RD PG: -33183.698167044735
# onehotencoder__nearest_park_name_PUNGGOL PK: 6600.609225822626
# onehotencoder__nearest_park_name_PUNGGOL WATERWAY PK: 3507.1306643621206
# onehotencoder__nearest_park_name_RAIL CORRIDOR: 1114.557714241841
# onehotencoder__nearest_park_name_REALTY PARK: -7718.330648980142
# onehotencoder__nearest_park_name_ROWELL RD OS: -22020.20729216891
# onehotencoder__nearest_park_name_SBG LC ZONE 1 (TNC): -18087.918089163726
# onehotencoder__nearest_park_name_SBG LC ZONE 2 (CC/BTC): 5216.580130875121
# onehotencoder__nearest_park_name_SEA BREEZE AVENUE PARK: 16519.724713915144
# onehotencoder__nearest_park_name_SEA BREEZE GARDEN PARK: 9084.169204619226
# onehotencoder__nearest_park_name_SEMBAWANG HOT SPRING PARK: -17407.770743364614
# onehotencoder__nearest_park_name_SENGKANG RIVERSIDE PK: -9242.689597169023
# onehotencoder__nearest_park_name_SENNETT AVE LINEAR PK: 8479.323107661512
# onehotencoder__nearest_park_name_SENNETT AVE OS: -1638.9674918184185
# onehotencoder__nearest_park_name_SERENADE WALK PG: 6902.727696025948
# onehotencoder__nearest_park_name_SG API API PK: -8779.005416846194
# onehotencoder__nearest_park_name_SIAN TUAN INTERIM PARK: 14753.717582989868
# onehotencoder__nearest_park_name_SIGLAP LINEAR PK (JLN B'WAN-UPP EC RD): -6039.316284626428
# onehotencoder__nearest_park_name_SILAT AVENUE PARK: -3627.666341633354
# onehotencoder__nearest_park_name_SOMME RD PG: 47618.76165231197
# onehotencoder__nearest_park_name_ST ANNE'S WOOD PG: -13405.977573217791
# onehotencoder__nearest_park_name_ST MICHAEL'S PG: -13274.56846920177
# onehotencoder__nearest_park_name_SUN PLAZA PK: -2652.274841357806
# onehotencoder__nearest_park_name_SUNSET WAY PG: -18040.013062237173
# onehotencoder__nearest_park_name_SURIN AVE NEIGHBOURHOOD PK: 12120.327067158674
# onehotencoder__nearest_park_name_TAI KENG GARDENS PG: -30721.67050372926
# onehotencoder__nearest_park_name_TAMAN MAS MERAH PLAYGROUND: 42201.61844266884
# onehotencoder__nearest_park_name_TAMAN PERMATA PK: -6914.641750079061
# onehotencoder__nearest_park_name_TAMPINES BOULEVARD PARK: -22837.55119947926
# onehotencoder__nearest_park_name_TAMPINES ECO GREEN PK: -3698.2448424832
# onehotencoder__nearest_park_name_TANAH MERAH PG: 2395.556082499341
# onehotencoder__nearest_park_name_TAVISTOCK AVE PK: -44127.335999938754
# onehotencoder__nearest_park_name_TELOK BLANGAH HILL PARK: -15754.761234978921
# onehotencoder__nearest_park_name_THE INGLEWOOD PG: -15472.788457231985
# onehotencoder__nearest_park_name_THOMSON PK: -25464.951010312157
# onehotencoder__nearest_park_name_THOMSON WALK PG: 38843.58089855994
# onehotencoder__nearest_park_name_TIONG BAHRU PK: 17744.252352421918
# onehotencoder__nearest_park_name_TOA PAYOH TOWN PK: 2298.896597797745
# onehotencoder__nearest_park_name_TRAS LINK PK: 4166.819967603434
# onehotencoder__nearest_park_name_UPPER SERANGOON PARK: 25292.90596810775
# onehotencoder__nearest_park_name_VILLA VERDE PK: -27941.492545769495
# onehotencoder__nearest_park_name_WAR MEMORIAL PK: 40309.412653895146
# onehotencoder__nearest_park_name_WARINGIN PK PG: -17316.90008020825
# onehotencoder__nearest_park_name_WEST COAST PARK: -941.4197831206316
# onehotencoder__nearest_park_name_WEST COAST PLACE PLAYGROUND: 18839.925577687132
# onehotencoder__nearest_park_name_WESTVILLE PLAYGROUND: -33585.59528052704
# onehotencoder__nearest_park_name_WESTWOOD PARK PLAYGROUND: -25164.94628018292
# onehotencoder__nearest_park_name_WILKINSON INTERIM PK: 25486.09229285771
# onehotencoder__nearest_park_name_WINDSOR NATURE PARK: 36852.45801434725
# onehotencoder__nearest_park_name_WOODLANDS HEALING GARDEN: -21296.06071817613
# onehotencoder__nearest_park_name_WOODLANDS TOWN PK EAST: -6476.3727865087685
# onehotencoder__nearest_park_name_WOODLANDS WATERFRONT PK: -47431.531359734436
# onehotencoder__nearest_park_name_YIO CHU KANG GARDENS PG: 14054.45728326376
# onehotencoder__nearest_park_name_YISHUN NEIGHBOURHOOD PK: 17061.32879282152
# onehotencoder__nearest_park_name_YISHUN PK: -30037.673844218058
# onehotencoder__nearest_park_name_YISHUN POND PK: 3218.588951265807
# onehotencoder__nearest_park_name_YUNNAN PARK: -17635.515560523396
# onehotencoder__nearest_park_name_ZHENGHUA NATURE PARK: -19209.88625411363
# onehotencoder__nearest_hawker_name_Aljunied Ave 2 Blk 117 (Blk 117 Aljunied Market and Food Centre): 23343.03654284918
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 1 Blk 226D (Kebun Baru Market and Food Centre): -15205.270146551413
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 1 Blk 341 (Teck Ghee Court): -142.64121217152046
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 10 Blk 409 (Teck Ghee Square): -4168.289821018437
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 10 Blk 453A (Chong Boon Market and Food Centre): 1073.2796165081572
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 10 Blk 527 (Cheng San Market and Cooked Food Centre): 6923.019402152697
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 4 Blk 160/162 (Mayflower Market): 17836.952091485924
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 4 Blk 628 (Ang Mo Kio 628 Market): 18874.935982607938
# onehotencoder__nearest_hawker_name_Ang Mo Kio Ave 6 Blk 724 (Blk 724 Ang Mo Kio Market): 3169.035627312881
# onehotencoder__nearest_hawker_name_Ang Mo Kio Street 22 Blk 226H (Kebun Baru Food Centre): 6811.684662300191
# onehotencoder__nearest_hawker_name_Bedok North Street 1 Blk 216: -802.5531672695354
# onehotencoder__nearest_hawker_name_Bedok North Street 3 Blk 511 (Kaki Bukit 511 Market and Food Centre): -25973.22992955667
# onehotencoder__nearest_hawker_name_Bedok North Street 3 Blk 538: -38690.05740935093
# onehotencoder__nearest_hawker_name_Bedok North Street 4 Blk 85 (85 Fengshan Centre): -16594.002864244114
# onehotencoder__nearest_hawker_name_Bedok Reservoir Road Blk 630: -546.6306194332285
# onehotencoder__nearest_hawker_name_Bedok South Road Blk 16: -961.6560017782479
# onehotencoder__nearest_hawker_name_Bendemeer Road Blk 29 (Bendemeer Market and Food Centre): 23647.4199431373
# onehotencoder__nearest_hawker_name_Beo Crescent Market: 26493.143585493828
# onehotencoder__nearest_hawker_name_Berseh Food Centre: -15749.316305712613
# onehotencoder__nearest_hawker_name_Boon Lay Place Blk 221A/B (Boon Lay Place Market and Food Village): -16659.626522181836
# onehotencoder__nearest_hawker_name_Buffalo Road Blk 665 (Tekka Centre/Zhu Jiao Market): -24989.577394530043
# onehotencoder__nearest_hawker_name_Bukit Merah Central Blk 163 (Bukit Merah Central Food Centre): -17189.469750169977
# onehotencoder__nearest_hawker_name_Bukit Merah Lane 1 Blk 120 (Alexandra Village Food Centre): -5835.705943027492
# onehotencoder__nearest_hawker_name_Bukit Merah View Blk 115 (Blk 115 Bukit Merah View Market and Food Centre): 2396.801576647587
# onehotencoder__nearest_hawker_name_Cambridge Road Blk 41A (Pek Kio Market and Food Centre): 21128.53971747636
# onehotencoder__nearest_hawker_name_Changi Village Blk 2 and 3: -3680.1427381811523
# onehotencoder__nearest_hawker_name_Chomp Chomp Food Centre: -7980.4967729044165
# onehotencoder__nearest_hawker_name_Circuit Road Blk 79/79A: -8402.753170441394
# onehotencoder__nearest_hawker_name_Circuit Road Blk 80 (80 Circuit Road Market and Food Centre): -5305.034055177973
# onehotencoder__nearest_hawker_name_Circuit Road Blk 89: -22565.91485131914
# onehotencoder__nearest_hawker_name_Clementi Ave 2 Blk 353 (Clementi Ave 2 Market/Cooked Food Centre): 52657.51559101911
# onehotencoder__nearest_hawker_name_Clementi Ave 3 Blk 448: 60462.59963893654
# onehotencoder__nearest_hawker_name_Clementi West Street 2 Blk 726: -14667.235331749816
# onehotencoder__nearest_hawker_name_Commonwealth Crescent Market: -41282.18223735309
# onehotencoder__nearest_hawker_name_Empress Road Blk 7 (Empress Road Market and Food Centre): 14678.940885927757
# onehotencoder__nearest_hawker_name_Eunos Crescent Blk 4A: 3595.6896194037854
# onehotencoder__nearest_hawker_name_Geylang Bahru Blk 69 (Blk 69 Geylang Bahru Market and Food Centre): 30026.206717240173
# onehotencoder__nearest_hawker_name_Geylang Serai Market: 11031.993208070719
# onehotencoder__nearest_hawker_name_Ghim Moh Road Blk 20: -34162.17141481751
# onehotencoder__nearest_hawker_name_Golden Mile Food Centre: 10979.276568305337
# onehotencoder__nearest_hawker_name_Haig Road Blk 13/14 (Haig Road Market and Cooked Food Centre): -2017.0721393559684
# onehotencoder__nearest_hawker_name_Havelock Road Blk 22A/B (Havelock Road Cooked Food Centre): 650.4123056780503
# onehotencoder__nearest_hawker_name_Holland Drive Blk 44 (Holland Drive Market and Food Centre): 11943.216448176698
# onehotencoder__nearest_hawker_name_Holland Village Market and Food Centre: 32931.18750054597
# onehotencoder__nearest_hawker_name_Hougang Ave 1 Blk 105 (Hougang 105 Hainanese Village Centre): -34395.4285975816
# onehotencoder__nearest_hawker_name_Hougang Street 21 Blk 209 (Kovan Hougang Market and Food Centre): 2394.1240358898026
# onehotencoder__nearest_hawker_name_Jalan Batu Blk 4A (Blk 4A Jalan Batu Hawker Centre/Market): -13339.738952544436
# onehotencoder__nearest_hawker_name_Jalan Bukit Merah Blk 112 (Blk 112 Jalan Bukit Merah Market and Food Centre): 20659.268071481045
# onehotencoder__nearest_hawker_name_Jalan Bukit Merah Blk 6 (ABC Brickworks Market/Food Centre): -9892.541953685666
# onehotencoder__nearest_hawker_name_Jalan Kukoh Blk 1 (Kukoh 21 Food Centre): -14516.864897057549
# onehotencoder__nearest_hawker_name_Jurong East Ave 1 Blk 347 (Yuhua Market and Hawker Centre): -18318.12980389444
# onehotencoder__nearest_hawker_name_Jurong East Street 24 Blk 254 (Yuhua Village Market and Food Centre): -11011.343341714757
# onehotencoder__nearest_hawker_name_Jurong West Street 52 Blk 505: -12986.796557507567
# onehotencoder__nearest_hawker_name_Kallang Estate Fresh Market and Food Centre: 79027.8316103344
# onehotencoder__nearest_hawker_name_Marine Parade Central Blk 84 (84 Marine Parade Central Market and Food Centre): 45730.558177204526
# onehotencoder__nearest_hawker_name_Marine Terrace Blk 50A (50A Marine Terrace): -16317.76688003947
# onehotencoder__nearest_hawker_name_Marsiling Lane Blk 20/21: -42518.80418496588
# onehotencoder__nearest_hawker_name_Mei Chin Road Blk 159 (Mei Chin Road Market): 5390.317060356384
# onehotencoder__nearest_hawker_name_New Market Road Blk 32 (People's Park Food Centre): -14230.590847364996
# onehotencoder__nearest_hawker_name_New Upper Changi Road Blk 208B: -1183.752583906493
# onehotencoder__nearest_hawker_name_New Upper Changi Road Blk 58: -9443.717557718213
# onehotencoder__nearest_hawker_name_North Bridge Road Market: 3661.216212479742
# onehotencoder__nearest_hawker_name_Old Airport Road Blk 51 (51 Old Airport Road Food Centre and Shopping Mall): 24515.613216959562
# onehotencoder__nearest_hawker_name_Pasir Panjang Food Centre: 1706.9564456448027
# onehotencoder__nearest_hawker_name_Queen Street Blk 270 (Albert Centre): 17871.726119520044
# onehotencoder__nearest_hawker_name_Redhill Lane Blk 79 (Redhill Market): 16213.285844116726
# onehotencoder__nearest_hawker_name_Redhill Lane Blk 85 (Redhill Food Centre): 39589.32419025367
# onehotencoder__nearest_hawker_name_Sembawang Hills Food Centre (Jalan Leban Food Centre): -19238.473013097457
# onehotencoder__nearest_hawker_name_Serangoon Garden Market: 11443.376825377776
# onehotencoder__nearest_hawker_name_Shunfu Road Blk 320 (Shunfu Mart): -12139.565732905254
# onehotencoder__nearest_hawker_name_Sims Place Blk 49 (Sims Vista Market and Food Centre): -7321.189982138534
# onehotencoder__nearest_hawker_name_Smith Street Blk 335 (Chinatown Complex Market): -6005.476220718604
# onehotencoder__nearest_hawker_name_Taman Jurong Market and Food Centre: -65773.80434994056
# onehotencoder__nearest_hawker_name_Tampines Street 11 Blk 137 (Tampines Round Market and Food Centre): 1130.182930004726
# onehotencoder__nearest_hawker_name_Tanglin Halt Market: -42131.40978044082
# onehotencoder__nearest_hawker_name_Tanjong Pagar Plaza Blk 6 (Blk 6 Tanjong Pagar Plaza Market and Food Centre): 68092.80143618137
# onehotencoder__nearest_hawker_name_Teban Gardens Road Blk 37A (Teban Gardens Market and Food Centre): -57084.46178153809
# onehotencoder__nearest_hawker_name_Telok Blangah Crescent Blk 11 (11 Telok Blangah Crescent Market and Food Centre): -21071.806363154
# onehotencoder__nearest_hawker_name_Telok Blangah Drive Blk 79 (Telok Blangah Food Centre): -16174.664591596738
# onehotencoder__nearest_hawker_name_Telok Blangah Drive Blk 82 (Telok Blangah Market): 5130.001982577424
# onehotencoder__nearest_hawker_name_Telok Blangah Rise Blk 36 (Telok Blangah Rise Market): -29140.577014318173
# onehotencoder__nearest_hawker_name_Tiong Bahru Market: 63065.01390108053
# onehotencoder__nearest_hawker_name_Toa Payoh Lorong 1 Blk 127 (Toa Payoh West Market and Food Court): 20916.942488105517
# onehotencoder__nearest_hawker_name_Toa Payoh Lorong 4 Blk 74 (Toa Payoh Vista Market): 7636.076767610844
# onehotencoder__nearest_hawker_name_Toa Payoh Lorong 4 Blk 93: 4585.992558708341
# onehotencoder__nearest_hawker_name_Toa Payoh Lorong 5 Blk 75: -30123.11177188953
# onehotencoder__nearest_hawker_name_Toa Payoh Lorong 7 Blk 22 (Kim Keat Palm Market and Food Centre): -26885.8248139194
# onehotencoder__nearest_hawker_name_Toa Payoh Lorong 8 Blk 210: -11484.138998685445
# onehotencoder__nearest_hawker_name_Upper Boon Keng Road Blk 17 (Blk 17 Upper Boon Keng Market and Food Centre): 14961.521736353114
# onehotencoder__nearest_hawker_name_Upper Cross Street Blk 531A (Hong Lim Food Centre and Market): 8345.892469566115
# onehotencoder__nearest_hawker_name_West Coast Drive Blk 503 (Ayer Rajah Food Centre): -9348.616028067678
# onehotencoder__nearest_hawker_name_Whampoa Drive Blk 90 (Whampoa Drive Makan Place/Whampoa Food Centre): -7291.401109237453
# onehotencoder__nearest_hawker_name_Whampoa Drive Blk 91/92 (Whampoa Drive Makan Place/Whampoa Market): -3531.4273460870386
# onehotencoder__nearest_hawker_name_Yishun Ring Road Blk 104/105 (Chong Pang Market and Food Centre): -33797.88539765533
# onehotencoder__nearest_hawker_name_Zion Riverside Food Centre: 72330.84891131599
# pipeline__floor_area_sqm: 1128203.26000347
# pipeline__sold_year: 280353.2487813747
# pipeline__remaining_lease: 288167.014611698
# pipeline__max_floor_lvl: 51997.80036991236
# intercept: 163354.75283433503

# %%
# Converting to DataFrame
feature_coefficients_df = pd.DataFrame(list(feature_coefficients.items()), columns=['Feature', 'Coefficient'])
feature_coefficients_df.head()
# Out:
#                              Feature   Coefficient
# 0          onehotencoder__town_BEDOK  66239.821169
# 1         onehotencoder__town_BISHAN  23081.270104
# 2    onehotencoder__town_BUKIT BATOK -33028.480021
# 3    onehotencoder__town_BUKIT MERAH  -2233.981797
# 4  onehotencoder__town_BUKIT PANJANG -58118.920275

# %%
# Sorting the DataFrame by the absolute values of the 'Coefficient' column
feature_coefficients_df = feature_coefficients_df.sort_values(by='Coefficient', key=abs, ascending=False)
feature_coefficients_df.head(15)
# Out:
#                                                  Feature   Coefficient
# 10846                           pipeline__floor_area_sqm  1.128203e+06
# 61                     onehotencoder__flat_model_Terrace  4.161611e+05
# 10848                          pipeline__remaining_lease  2.881670e+05
# 10847                                pipeline__sold_year  2.803532e+05
# 5549   onehotencoder__matched_address_445A CLEMENTI A...  2.105054e+05
# 5552   onehotencoder__matched_address_445B CLEMENTI A...  2.096881e+05
# 1520   onehotencoder__matched_address_160 BISHAN STRE...  1.954870e+05
# 273    onehotencoder__matched_address_105B BIDADARI P...  1.940722e+05
# 270    onehotencoder__matched_address_105A BIDADARI P...  1.860244e+05
# 3250   onehotencoder__matched_address_26B SAINT GEORG...  1.853491e+05
# 2635   onehotencoder__matched_address_228B ANG MO KIO...  1.823200e+05
# 5459   onehotencoder__matched_address_44 LENGKOK BAHR...  1.778527e+05
# 7104   onehotencoder__matched_address_60 JALAN BAHAGI... -1.730425e+05
# 4410   onehotencoder__matched_address_343 JURONG EAST...  1.657461e+05
# 10850                                          intercept  1.633548e+05

# %% [markdown]
# **Comments**
#
# Model seems to make sense, as floor_area_sqm is the single strongest predictor of price, followed by the closest MRT station to the HDB, the year it was sold, and walking times to the closest MRT.

# %% [markdown]
# #### Plots to Evaluate Model Performance ####
# ##### Residual Plot

# %%
# Get residuals
residuals = y_test - y_pred

# Plot
plt.figure(figsize=(10, 6))
sns.residplot(x=y_pred, y=residuals, scatter_kws={"alpha": 0.3})
plt.title('Residual Plot')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# **Comments**
#
# - The residuals fan out as predicted values increase, indicating heteroscedasticity — the model's precision weakens at higher predictor values. Data points are denser at lower predicted values, suggesting better accuracy in that range, though notably few extreme outliers are present.
#
# **Conclusion**
#
# - While the absence of any curved pattern is encouraging, the fanning of residuals signals non-constant error variance, violating a key linear regression assumption. Transforming the dependent variable or incorporating non-linear terms may help address this and improve the model.

# %% [markdown]
# ##### Histogram of Residuals

# %%
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True)
plt.title('Histogram of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Comments**
#
# - The residuals form an approximately symmetrical, bell-shaped distribution centered around zero, with the fitted curve closely following a normal distribution. This suggests the residuals do not deviate significantly from normality — a key assumption of linear regression.
#
# **Conclusion**
#
# - Overall, the histogram indicates that the normality assumption is reasonably satisfied. The symmetry around zero reflects an absence of systematic bias in the model's predictions, and the tails show no signs of heavy skewness or extreme outliers, further supporting the model's suitability for the data.

# %% [markdown]
# ##### Q-Q Plot

# %%
plt.figure(figsize=(10, 6))
stats.probplot(residuals, dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.show()

# %% [markdown]
# **Comments**
#
# - The red reference line marks perfect normality, while the blue dots represent the actual data quantiles plotted against their theoretical counterparts. Points in the central region closely follow the reference line, indicating approximate normality there. However, deviations emerge in both tails — the lower tail dips below and the upper tail rises above the line — forming a slight S-shape that suggests the distribution has a higher peak and heavier tails than a normal distribution.
#
# **Conclusion**
#
# - While the center of the distribution appears approximately normal, the heavier tails indicated by the Q-Q plot raise concerns about the normality assumption. This may warrant variable transformations or alternative modeling approaches to better handle the distributional characteristics of the data.
